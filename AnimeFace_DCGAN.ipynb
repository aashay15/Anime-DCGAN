# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# try to run the bare minimum to get a new conda env working
conda_path = '/usr/local/bin/conda'
try:
    conda_path = !which conda
finally:
    print('')

if (len(conda_path) == 0):
    print('installing miniconda')
    # !wget https://repo.continuum.io/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh && bash Miniconda3-4.5.4-Linux-x86_64.sh -bfp /usr/local
    # !conda update conda -y -q
    # !source /usr/local/etc/profile.d/conda.sh
    # !conda init 
    # !conda install -n root _license -y -q
else:
    print('found miniconda')

conda_envs = !conda env list
res = [i for i in conda_envs if 'test36' in i]
if (len(res) == 0):
    print('not found test36 env', len(res))
    # !conda create -y -q --name test36 python=3.6 libarchive cartopy
else:
    print('found test36 env', len(res))
# Out:
# installing miniconda
# --2020-09-13 09:14:35--  https://repo.continuum.io/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh [following]
# --2020-09-13 09:14:35--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58468498 (56M) [application/x-sh]
# Saving to: ‘Miniconda3-4.5.4-Linux-x86_64.sh’
#
# Miniconda3-4.5.4-Li 100%[===================>]  55.76M   179MB/s    in 0.3s
#
# 2020-09-13 09:14:36 (179 MB/s) - ‘Miniconda3-4.5.4-Linux-x86_64.sh’ saved [58468498/58468498]
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# installing: ruamel_yaml-0.15.37-py36h14c3975_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: cffi-1.11.5-py36h9745a5d_0 ...
# installing: setuptools-39.2.0-py36_0 ...
# installing: cryptography-2.2.2-py36h14c3975_0 ...
# installing: wheel-0.31.1-py36_0 ...
# installing: pip-10.0.1-py36_0 ...
# installing: pyopenssl-18.0.0-py36_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: conda-4.5.4-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     urllib3-1.25.10            |             py_0          93 KB
#     yaml-0.2.5                 |       h7b6447c_0          87 KB
#     setuptools-49.6.0          |           py37_0         909 KB
#     ca-certificates-2020.7.22  |                0         132 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     _libgcc_mutex-0.1          |             main           3 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     conda-4.8.4                |           py37_0         3.0 MB
#     wheel-0.35.1               |             py_0          36 KB
#     openssl-1.0.2u             |       h7b6447c_0         3.1 MB
#     tqdm-4.48.2                |             py_0          63 KB
#     brotlipy-0.7.0             |py37h7b6447c_1000         348 KB
#     ruamel_yaml-0.15.87        |   py37h7b6447c_1         253 KB
#     conda-package-handling-1.6.1|   py37h7b6447c_0         886 KB
#     cryptography-2.3.1         |   py37hc365091_0         585 KB
#     pycparser-2.20             |             py_2          94 KB
#     idna-2.10                  |             py_0          56 KB
#     pip-20.2.2                 |           py37_0         2.0 MB
#     certifi-2020.6.20          |           py37_0         159 KB
#     readline-7.0               |       h7b6447c_5         392 KB
#     asn1crypto-1.4.0           |             py_0          77 KB
#     libedit-3.1.20181209       |       hc058e9b_0         188 KB
#     chardet-3.0.4              |        py37_1003         173 KB
#     pycosat-0.6.3              |   py37h7b6447c_0         107 KB
#     tk-8.6.10                  |       hbc83047_0         3.2 MB
#     pysocks-1.7.1              |           py37_1          27 KB
#     six-1.15.0                 |             py_0          13 KB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     pyopenssl-19.0.0           |           py37_0          82 KB
#     python-3.7.0               |       hc3d631a_0        31.7 MB
#     cffi-1.14.0                |   py37h2e261b9_0         225 KB
#     requests-2.24.0            |             py_0          54 KB
#     sqlite-3.31.1              |       h7b6447c_0         2.0 MB
#     ------------------------------------------------------------
#                                            Total:        58.7 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:          0.1-main
#     brotlipy:               0.7.0-py37h7b6447c_1000
#     conda-package-handling: 1.6.1-py37h7b6447c_0
#     tqdm:                   4.48.2-py_0
#
# The following packages will be UPDATED:
#
#     asn1crypto:             0.24.0-py36_0           --> 1.4.0-py_0
#     ca-certificates:        2018.03.07-0            --> 2020.7.22-0
#     certifi:                2018.4.16-py36_0        --> 2020.6.20-py37_0
#     cffi:                   1.11.5-py36h9745a5d_0   --> 1.14.0-py37h2e261b9_0
#     chardet:                3.0.4-py36h0f667ec_1    --> 3.0.4-py37_1003
#     conda:                  4.5.4-py36_0            --> 4.8.4-py37_0
#     cryptography:           2.2.2-py36h14c3975_0    --> 2.3.1-py37hc365091_0
#     idna:                   2.6-py36h82fb2a8_1      --> 2.10-py_0
#     libedit:                3.1.20170329-h6b74fdf_2 --> 3.1.20181209-hc058e9b_0
#     libgcc-ng:              7.2.0-hdf63c60_3        --> 9.1.0-hdf63c60_0
#     openssl:                1.0.2o-h20670df_0       --> 1.0.2u-h7b6447c_0
#     pip:                    10.0.1-py36_0           --> 20.2.2-py37_0
#     pycosat:                0.6.3-py36h0a5515d_0    --> 0.6.3-py37h7b6447c_0
#     pycparser:              2.18-py36hf9f622e_1     --> 2.20-py_2
#     pyopenssl:              18.0.0-py36_0           --> 19.0.0-py37_0
#     pysocks:                1.6.8-py36_0            --> 1.7.1-py37_1
#     python:                 3.6.5-hc3d631a_2        --> 3.7.0-hc3d631a_0
#     readline:               7.0-ha6073c6_4          --> 7.0-h7b6447c_5
#     requests:               2.18.4-py36he2e5f8d_1   --> 2.24.0-py_0
#     ruamel_yaml:            0.15.37-py36h14c3975_2  --> 0.15.87-py37h7b6447c_1
#     setuptools:             39.2.0-py36_0           --> 49.6.0-py37_0
#     six:                    1.11.0-py36h372c433_1   --> 1.15.0-py_0
#     sqlite:                 3.23.1-he433501_0       --> 3.31.1-h7b6447c_0
#     tk:                     8.6.7-hc745277_3        --> 8.6.10-hbc83047_0
#     urllib3:                1.22-py36hbe7ace6_0     --> 1.25.10-py_0
#     wheel:                  0.31.1-py36_0           --> 0.35.1-py_0
#     xz:                     5.2.4-h14c3975_4        --> 5.2.5-h7b6447c_0
#     yaml:                   0.1.7-had09818_2        --> 0.2.5-h7b6447c_0
#     zlib:                   1.2.11-ha838bed_2       --> 1.2.11-h7b6447c_3
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - _license
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# not found test36 env 0
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/test36
#
#   added / updated specs:
#     - cartopy
#     - libarchive
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     blas-1.0                   |              mkl           6 KB
#     brotlipy-0.7.0             |py36h7b6447c_1000         323 KB
#     bzip2-1.0.8                |       h7b6447c_0          78 KB
#     ca-certificates-2020.7.22  |                0         125 KB
#     cartopy-0.18.0             |   py36hee755e7_0         1.7 MB
#     certifi-2020.6.20          |           py36_0         156 KB
#     cffi-1.14.2                |   py36he30daa8_0         227 KB
#     chardet-3.0.4              |        py36_1003         180 KB
#     cryptography-3.1           |   py36h1ba5d50_0         562 KB
#     cycler-0.10.0              |           py36_0          13 KB
#     dbus-1.13.16               |       hb2f20db_0         501 KB
#     expat-2.2.9                |       he6710b0_2         156 KB
#     fontconfig-2.13.0          |       h9420a91_0         227 KB
#     freetype-2.10.2            |       h5ab3b9f_0         608 KB
#     geos-3.8.0                 |       he6710b0_0         961 KB
#     glib-2.65.0                |       h3eb4bd4_0         2.9 MB
#     gst-plugins-base-1.14.0    |       hbbd80ab_1         4.8 MB
#     gstreamer-1.14.0           |       hb31296c_0         3.1 MB
#     icu-58.2                   |       he6710b0_3        10.5 MB
#     idna-2.10                  |             py_0          50 KB
#     intel-openmp-2020.2        |              254         786 KB
#     jpeg-9b                    |       h024ee3a_2         214 KB
#     kiwisolver-1.2.0           |   py36hfd86e86_0          84 KB
#     lcms2-2.11                 |       h396b838_0         307 KB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         568 KB
#     libarchive-3.4.2           |       h62408e4_0         796 KB
#     libedit-3.1.20191231       |       h14c3975_1         116 KB
#     libffi-3.3                 |       he6710b0_2          50 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         5.1 MB
#     libgfortran-ng-7.3.0       |       hdf63c60_0        1006 KB
#     libpng-1.6.37              |       hbc83047_0         278 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         3.1 MB
#     libtiff-4.1.0              |       h2733197_1         449 KB
#     libuuid-1.0.3              |       h1bed415_2          15 KB
#     libxcb-1.14                |       h7b6447c_0         505 KB
#     libxml2-2.9.10             |       he19cac6_1         1.2 MB
#     lz4-c-1.9.2                |       he6710b0_1         190 KB
#     matplotlib-3.3.1           |                0          24 KB
#     matplotlib-base-3.3.1      |   py36h817c723_0         5.1 MB
#     mkl-2020.2                 |              256       138.3 MB
#     mkl-service-2.3.0          |   py36he904b0f_0         219 KB
#     mkl_fft-1.1.0              |   py36h23d657b_0         144 KB
#     mkl_random-1.1.1           |   py36h0573a6f_0         327 KB
#     ncurses-6.2                |       he6710b0_1         817 KB
#     numpy-1.19.1               |   py36hbc911f0_0          21 KB
#     numpy-base-1.19.1          |   py36hfa32c7d_0         4.1 MB
#     olefile-0.46               |           py36_0          48 KB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     owslib-0.20.0              |             py_0         123 KB
#     pcre-8.44                  |       he6710b0_0         212 KB
#     pillow-7.2.0               |   py36hb39fc2d_0         619 KB
#     pip-20.2.2                 |           py36_0         1.8 MB
#     proj-6.2.1                 |       haa6030c_0         9.0 MB
#     pycparser-2.20             |             py_2          94 KB
#     pyepsg-0.4.0               |           py36_0          26 KB
#     pykdtree-1.3.1             |   py36hdd07704_2          61 KB
#     pyopenssl-19.1.0           |             py_1          48 KB
#     pyparsing-2.4.7            |             py_0          65 KB
#     pyproj-2.6.1.post1         |   py36hd003209_1         390 KB
#     pyqt-5.9.2                 |   py36h05f1152_2         4.5 MB
#     pyshp-2.1.1                |             py_0          35 KB
#     pysocks-1.7.1              |           py36_0          30 KB
#     python-3.6.12              |       hcff3b4d_2        29.7 MB
#     python-dateutil-2.8.1      |             py_0         215 KB
#     pytz-2020.1                |             py_0         184 KB
#     pyyaml-5.3.1               |   py36h7b6447c_1         180 KB
#     qt-5.9.7                   |       h5867ecd_1        68.5 MB
#     readline-8.0               |       h7b6447c_0         356 KB
#     requests-2.24.0            |             py_0          56 KB
#     scipy-1.5.2                |   py36h0b6359f_0        14.4 MB
#     setuptools-49.6.0          |           py36_0         757 KB
#     shapely-1.7.1              |   py36h98ec03d_0         392 KB
#     sip-4.19.8                 |   py36hf484d3e_0         274 KB
#     six-1.15.0                 |             py_0          13 KB
#     sqlite-3.33.0              |       h62c20be_0         1.1 MB
#     tk-8.6.10                  |       hbc83047_0         3.0 MB
#     tornado-6.0.4              |   py36h7b6447c_1         597 KB
#     urllib3-1.25.10            |             py_0          98 KB
#     wheel-0.35.1               |             py_0          37 KB
#     xz-5.2.5                   |       h7b6447c_0         341 KB
#     yaml-0.2.5                 |       h7b6447c_0          75 KB
#     zlib-1.2.11                |       h7b6447c_3         103 KB
#     zstd-1.4.5                 |       h9ceee32_0         619 KB
#     ------------------------------------------------------------
#                                            Total:       331.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py36h7b6447c_1000
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h7b6447c_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.7.22-0
#   cartopy            pkgs/main/linux-64::cartopy-0.18.0-py36hee755e7_0
#   certifi            pkgs/main/linux-64::certifi-2020.6.20-py36_0
#   cffi               pkgs/main/linux-64::cffi-1.14.2-py36he30daa8_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py36_1003
#   cryptography       pkgs/main/linux-64::cryptography-3.1-py36h1ba5d50_0
#   cycler             pkgs/main/linux-64::cycler-0.10.0-py36_0
#   dbus               pkgs/main/linux-64::dbus-1.13.16-hb2f20db_0
#   expat              pkgs/main/linux-64::expat-2.2.9-he6710b0_2
#   fontconfig         pkgs/main/linux-64::fontconfig-2.13.0-h9420a91_0
#   freetype           pkgs/main/linux-64::freetype-2.10.2-h5ab3b9f_0
#   geos               pkgs/main/linux-64::geos-3.8.0-he6710b0_0
#   glib               pkgs/main/linux-64::glib-2.65.0-h3eb4bd4_0
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.0-hbbd80ab_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.0-hb31296c_0
#   icu                pkgs/main/linux-64::icu-58.2-he6710b0_3
#   idna               pkgs/main/noarch::idna-2.10-py_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2020.2-254
#   jpeg               pkgs/main/linux-64::jpeg-9b-h024ee3a_2
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.2.0-py36hfd86e86_0
#   lcms2              pkgs/main/linux-64::lcms2-2.11-h396b838_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libarchive         pkgs/main/linux-64::libarchive-3.4.2-h62408e4_0
#   libedit            pkgs/main/linux-64::libedit-3.1.20191231-h14c3975_1
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.3.0-hdf63c60_0
#   libpng             pkgs/main/linux-64::libpng-1.6.37-hbc83047_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   libtiff            pkgs/main/linux-64::libtiff-4.1.0-h2733197_1
#   libuuid            pkgs/main/linux-64::libuuid-1.0.3-h1bed415_2
#   libxcb             pkgs/main/linux-64::libxcb-1.14-h7b6447c_0
#   libxml2            pkgs/main/linux-64::libxml2-2.9.10-he19cac6_1
#   lz4-c              pkgs/main/linux-64::lz4-c-1.9.2-he6710b0_1
#   matplotlib         pkgs/main/linux-64::matplotlib-3.3.1-0
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.3.1-py36h817c723_0
#   mkl                pkgs/main/linux-64::mkl-2020.2-256
#   mkl-service        pkgs/main/linux-64::mkl-service-2.3.0-py36he904b0f_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.1.0-py36h23d657b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.1.1-py36h0573a6f_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_1
#   numpy              pkgs/main/linux-64::numpy-1.19.1-py36hbc911f0_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.19.1-py36hfa32c7d_0
#   olefile            pkgs/main/linux-64::olefile-0.46-py36_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1g-h7b6447c_0
#   owslib             pkgs/main/noarch::owslib-0.20.0-py_0
#   pcre               pkgs/main/linux-64::pcre-8.44-he6710b0_0
#   pillow             pkgs/main/linux-64::pillow-7.2.0-py36hb39fc2d_0
#   pip                pkgs/main/linux-64::pip-20.2.2-py36_0
#   proj               pkgs/main/linux-64::proj-6.2.1-haa6030c_0
#   pycparser          pkgs/main/noarch::pycparser-2.20-py_2
#   pyepsg             pkgs/main/linux-64::pyepsg-0.4.0-py36_0
#   pykdtree           pkgs/main/linux-64::pykdtree-1.3.1-py36hdd07704_2
#   pyopenssl          pkgs/main/noarch::pyopenssl-19.1.0-py_1
#   pyparsing          pkgs/main/noarch::pyparsing-2.4.7-py_0
#   pyproj             pkgs/main/linux-64::pyproj-2.6.1.post1-py36hd003209_1
#   pyqt               pkgs/main/linux-64::pyqt-5.9.2-py36h05f1152_2
#   pyshp              pkgs/main/noarch::pyshp-2.1.1-py_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py36_0
#   python             pkgs/main/linux-64::python-3.6.12-hcff3b4d_2
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.1-py_0
#   pytz               pkgs/main/noarch::pytz-2020.1-py_0
#   pyyaml             pkgs/main/linux-64::pyyaml-5.3.1-py36h7b6447c_1
#   qt                 pkgs/main/linux-64::qt-5.9.7-h5867ecd_1
#   readline           pkgs/main/linux-64::readline-8.0-h7b6447c_0
#   requests           pkgs/main/noarch::requests-2.24.0-py_0
#   scipy              pkgs/main/linux-64::scipy-1.5.2-py36h0b6359f_0
#   setuptools         pkgs/main/linux-64::setuptools-49.6.0-py36_0
#   shapely            pkgs/main/linux-64::shapely-1.7.1-py36h98ec03d_0
#   sip                pkgs/main/linux-64::sip-4.19.8-py36hf484d3e_0
#   six                pkgs/main/noarch::six-1.15.0-py_0
#   sqlite             pkgs/main/linux-64::sqlite-3.33.0-h62c20be_0
#   tk                 pkgs/main/linux-64::tk-8.6.10-hbc83047_0
#   tornado            pkgs/main/linux-64::tornado-6.0.4-py36h7b6447c_1
#   urllib3            pkgs/main/noarch::urllib3-1.25.10-py_0
#   wheel              pkgs/main/noarch::wheel-0.35.1-py_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#   zstd               pkgs/main/linux-64::zstd-1.4.5-h9ceee32_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# %%bash
# source activate test36
# conda env list
# conda list
# python
# import sys
# #import libarchive
# # maybe only need this the first time we run this notebook
# sys.path.append('/usr/local/lib/python3.6/site-packages')
#
# print("Python version")
# print(sys.version)
# Out:
# # conda environments:
# #
# base                     /usr/local
# test36                *  /usr/local/envs/test36
#
# # packages in environment at /usr/local/envs/test36:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# blas                      1.0                         mkl
# brotlipy                  0.7.0           py36h7b6447c_1000
# bzip2                     1.0.8                h7b6447c_0
# ca-certificates           2020.7.22                     0
# cartopy                   0.18.0           py36hee755e7_0
# certifi                   2020.6.20                py36_0
# cffi                      1.14.2           py36he30daa8_0
# chardet                   3.0.4                 py36_1003
# cryptography              3.1              py36h1ba5d50_0
# cycler                    0.10.0                   py36_0
# dbus                      1.13.16              hb2f20db_0
# expat                     2.2.9                he6710b0_2
# fontconfig                2.13.0               h9420a91_0
# freetype                  2.10.2               h5ab3b9f_0
# geos                      3.8.0                he6710b0_0
# glib                      2.65.0               h3eb4bd4_0
# gst-plugins-base          1.14.0               hbbd80ab_1
# gstreamer                 1.14.0               hb31296c_0
# icu                       58.2                 he6710b0_3
# idna                      2.10                       py_0
# intel-openmp              2020.2                      254
# jpeg                      9b                   h024ee3a_2
# kiwisolver                1.2.0            py36hfd86e86_0
# lcms2                     2.11                 h396b838_0
# ld_impl_linux-64          2.33.1               h53a641e_7
# libarchive                3.4.2                h62408e4_0
# libedit                   3.1.20191231         h14c3975_1
# libffi                    3.3                  he6710b0_2
# libgcc-ng                 9.1.0                hdf63c60_0
# libgfortran-ng            7.3.0                hdf63c60_0
# libpng                    1.6.37               hbc83047_0
# libstdcxx-ng              9.1.0                hdf63c60_0
# libtiff                   4.1.0                h2733197_1
# libuuid                   1.0.3                h1bed415_2
# libxcb                    1.14                 h7b6447c_0
# libxml2                   2.9.10               he19cac6_1
# lz4-c                     1.9.2                he6710b0_1
# matplotlib                3.3.1                         0
# matplotlib-base           3.3.1            py36h817c723_0
# mkl                       2020.2                      256
# mkl-service               2.3.0            py36he904b0f_0
# mkl_fft                   1.1.0            py36h23d657b_0
# mkl_random                1.1.1            py36h0573a6f_0
# ncurses                   6.2                  he6710b0_1
# numpy                     1.19.1           py36hbc911f0_0
# numpy-base                1.19.1           py36hfa32c7d_0
# olefile                   0.46                     py36_0
# openssl                   1.1.1g               h7b6447c_0
# owslib                    0.20.0                     py_0
# pcre                      8.44                 he6710b0_0
# pillow                    7.2.0            py36hb39fc2d_0
# pip                       20.2.2                   py36_0
# proj                      6.2.1                haa6030c_0
# pycparser                 2.20                       py_2
# pyepsg                    0.4.0                    py36_0
# pykdtree                  1.3.1            py36hdd07704_2
# pyopenssl                 19.1.0                     py_1
# pyparsing                 2.4.7                      py_0
# pyproj                    2.6.1.post1      py36hd003209_1
# pyqt                      5.9.2            py36h05f1152_2
# pyshp                     2.1.1                      py_0
# pysocks                   1.7.1                    py36_0
# python                    3.6.12               hcff3b4d_2
# python-dateutil           2.8.1                      py_0
# pytz                      2020.1                     py_0
# pyyaml                    5.3.1            py36h7b6447c_1
# qt                        5.9.7                h5867ecd_1
# readline                  8.0                  h7b6447c_0
# requests                  2.24.0                     py_0
# scipy                     1.5.2            py36h0b6359f_0
# setuptools                49.6.0                   py36_0
# shapely                   1.7.1            py36h98ec03d_0
# sip                       4.19.8           py36hf484d3e_0
# six                       1.15.0                     py_0
# sqlite                    3.33.0               h62c20be_0
# tk                        8.6.10               hbc83047_0
# tornado                   6.0.4            py36h7b6447c_1
# urllib3                   1.25.10                    py_0
# wheel                     0.35.1                     py_0
# xz                        5.2.5                h7b6447c_0
# yaml                      0.2.5                h7b6447c_0
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.4.5                h9ceee32_0
# Python version
# 3.6.12 |Anaconda, Inc.| (default, Sep  8 2020, 23:10:56)
# [GCC 7.3.0]

# %%
# !pip install -r "/content/drive/My Drive/requirements.txt"
# Out:
# Collecting absl-py==0.5.0
#   Downloading absl-py-0.5.0.tar.gz (90 kB)
#      |████████████████████████████████| 90 kB 2.8 MB/s
# Collecting animeface==1.1.0
#   Downloading animeface-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 10.9 MB/s
# Collecting astor==0.7.1
#   Downloading astor-0.7.1-py2.py3-none-any.whl (27 kB)
# Collecting certifi==2018.10.15
#   Downloading certifi-2018.10.15-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 39.2 MB/s
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.7/site-packages (from -r /content/drive/My Drive/requirements.txt (line 5)) (3.0.4)
# Collecting cloudpickle==0.6.1
#   Downloading cloudpickle-0.6.1-py2.py3-none-any.whl (14 kB)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting dask==0.20.2
#   Downloading dask-0.20.2-py2.py3-none-any.whl (686 kB)
#      |████████████████████████████████| 686 kB 39.5 MB/s
# Collecting decorator==4.3.0
#   Downloading decorator-4.3.0-py2.py3-none-any.whl (9.2 kB)
# Collecting gallery-dl==1.5.3
#   Downloading gallery_dl-1.5.3-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 40.7 MB/s
# Collecting gast==0.2.0
#   Downloading gast-0.2.0.tar.gz (9.4 kB)
# Collecting grpcio==1.15.0
#   Downloading grpcio-1.15.0-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 53.7 MB/s
# Collecting h5py==2.8.0
#   Downloading h5py-2.8.0-cp37-cp37m-manylinux1_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 75.1 MB/s
# Collecting idna==2.7
#   Downloading idna-2.7-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.2 MB/s
# Collecting Keras==2.2.4
#   Downloading Keras-2.2.4-py2.py3-none-any.whl (312 kB)
#      |████████████████████████████████| 312 kB 70.7 MB/s
# Collecting Keras-Applications==1.0.6
#   Downloading Keras_Applications-1.0.6-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 3.0 MB/s
# Collecting Keras-Preprocessing==1.0.5
#   Downloading Keras_Preprocessing-1.0.5-py2.py3-none-any.whl (30 kB)
# Collecting kiwisolver==1.0.1
#   Downloading kiwisolver-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (89 kB)
#      |████████████████████████████████| 89 kB 10.0 MB/s
# Collecting Markdown==3.0.1
#   Downloading Markdown-3.0.1-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 9.7 MB/s
# Collecting matplotlib==3.0.0
#   Downloading matplotlib-3.0.0-cp37-cp37m-manylinux1_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 50 kB/s
# Collecting networkx==2.2
#   Downloading networkx-2.2.zip (1.7 MB)
#      |████████████████████████████████| 1.7 MB 63.2 MB/s
# Collecting numpy==1.15.2
#   Downloading numpy-1.15.2-cp37-cp37m-manylinux1_x86_64.whl (13.8 MB)
#      |████████████████████████████████| 13.8 MB 35 kB/s
# Collecting Pillow==5.3.0
#   Downloading Pillow-5.3.0-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 59.5 MB/s
# Collecting protobuf==3.6.1
#   Downloading protobuf-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 58.3 MB/s
# Collecting pydot==1.2.4
#   Downloading pydot-1.2.4.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 79.8 MB/s
# Collecting pyparsing==2.2.2
#   Downloading pyparsing-2.2.2-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.5 MB/s
# Collecting python-dateutil==2.7.3
#   Downloading python_dateutil-2.7.3-py2.py3-none-any.whl (211 kB)
#      |████████████████████████████████| 211 kB 79.5 MB/s
# Collecting PyWavelets==1.0.1
#   Downloading PyWavelets-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 53.9 MB/s
# Collecting PyYAML==3.13
#   Downloading PyYAML-3.13.tar.gz (270 kB)
#      |████████████████████████████████| 270 kB 73.4 MB/s
# Collecting requests==2.20.0
#   Downloading requests-2.20.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 9.7 MB/s
# Collecting scikit-image==0.14.1
#   Downloading scikit_image-0.14.1-cp37-cp37m-manylinux1_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 40 kB/s
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 59 kB/s
# Collecting six==1.11.0
#   Downloading six-1.11.0-py2.py3-none-any.whl (10 kB)
# Collecting tensorboard==1.11.0
#   Downloading tensorboard-1.11.0-py3-none-any.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 20.8 MB/s
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.11.0 (from -r /content/drive/My Drive/requirements.txt (line 35)) (from versions: 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 1.15.2, 1.15.3, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0, 2.0.1, 2.0.2, 2.1.0rc0, 2.1.0rc1, 2.1.0rc2, 2.1.0, 2.1.1, 2.2.0rc0, 2.2.0rc1, 2.2.0rc2, 2.2.0rc3, 2.2.0rc4, 2.2.0, 2.3.0rc0, 2.3.0rc1, 2.3.0rc2, 2.3.0)
# ERROR: No matching distribution found for tensorflow==1.11.0 (from -r /content/drive/My Drive/requirements.txt (line 35))

# %%
# !pip install ipykernel
# Out:
# Collecting ipykernel
#   Downloading ipykernel-5.3.4-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 3.4 MB/s
# Collecting traitlets>=4.1.0
#   Downloading traitlets-5.0.4-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 6.0 MB/s
# Collecting tornado>=4.2
#   Downloading tornado-6.0.4.tar.gz (496 kB)
#      |████████████████████████████████| 496 kB 10.5 MB/s
# Collecting jupyter-client
#   Downloading jupyter_client-6.1.7-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 16.6 MB/s
# Collecting ipython>=5.0.0
#   Downloading ipython-7.18.1-py3-none-any.whl (786 kB)
#      |████████████████████████████████| 786 kB 16.6 MB/s
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyter-core>=4.6.0
#   Downloading jupyter_core-4.6.3-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.0 MB/s
# Collecting pyzmq>=13
#   Downloading pyzmq-19.0.2-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 19.9 MB/s
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/site-packages (from jupyter-client->ipykernel) (2.8.1)
# Collecting decorator
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting pygments
#   Downloading Pygments-2.7.0-py3-none-any.whl (950 kB)
#      |████████████████████████████████| 950 kB 30.9 MB/s
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.7-py3-none-any.whl (355 kB)
#      |████████████████████████████████| 355 kB 54.2 MB/s
# Collecting pexpect>4.3; sys_platform != "win32"
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 7.8 MB/s
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel) (49.6.0.post20200814)
# Collecting jedi>=0.10
#   Downloading jedi-0.17.2-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 42.2 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel) (1.15.0)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.6.0-py2.py3-none-any.whl (39 kB)
# Collecting parso<0.8.0,>=0.7.0
#   Downloading parso-0.7.1-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 65.6 MB/s
# Building wheels for collected packages: tornado
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-6.0.4-cp37-cp37m-linux_x86_64.whl size=428568 sha256=d14b1c63430900427deff5b2284a8ae5f823a94c9608bf4ebad64645de1c8b0d
#   Stored in directory: /root/.cache/pip/wheels/7d/14/fa/d88fb5da77d813ea0ffca38a2ab2a052874e9e1142bad0b348
# Successfully built tornado
# Installing collected packages: ipython-genutils, traitlets, tornado, jupyter-core, pyzmq, jupyter-client, decorator, pickleshare, pygments, backcall, wcwidth, prompt-toolkit, ptyprocess, pexpect, parso, jedi, ipython, ipykernel
# Successfully installed backcall-0.2.0 decorator-4.4.2 ipykernel-5.3.4 ipython-7.18.1 ipython-genutils-0.2.0 jedi-0.17.2 jupyter-client-6.1.7 jupyter-core-4.6.3 parso-0.7.1 pexpect-4.8.0 pickleshare-0.7.5 prompt-toolkit-3.0.7 ptyprocess-0.6.0 pygments-2.7.0 pyzmq-19.0.2 tornado-6.0.4 traitlets-5.0.4 wcwidth-0.2.5

# %%
# !python3 "/content/drive/My Drive/train.py"
# Out:
# Streaming output truncated to the last 5000 lines.
# d_loss :  0.33340683579444885
# g_loss: 1.9371888637542725
# Epoch:4783, dis_loss:0.3377157002687454
# Epoch:4783, gen_loss: 2.1138391494750977
# Batch:2
# d_loss :  0.3367138206958771
# g_loss: 2.476284980773926
# Epoch:4783, dis_loss:0.3373817404111226
# Epoch:4783, gen_loss: 2.234654426574707
# Batch:3
# d_loss :  0.3541821241378784
# g_loss: 2.1290392875671387
# Epoch:4783, dis_loss:0.3415818363428116
# Epoch:4783, gen_loss: 2.208250641822815
# --------------------------
# Epoch is 4784
# Number of Batches :  4
# Batch:0
# d_loss :  0.3370189219713211
# g_loss: 2.4027099609375
# Epoch:4784, dis_loss:0.3370189219713211
# Epoch:4784, gen_loss: 2.4027099609375
# Batch:1
# d_loss :  0.3381716161966324
# g_loss: 2.2747535705566406
# Epoch:4784, dis_loss:0.33759526908397675
# Epoch:4784, gen_loss: 2.3387317657470703
# Batch:2
# d_loss :  0.34270359575748444
# g_loss: 2.3565573692321777
# Epoch:4784, dis_loss:0.3392980446418126
# Epoch:4784, gen_loss: 2.3446736335754395
# Batch:3
# d_loss :  0.3407345116138458
# g_loss: 2.4301652908325195
# Epoch:4784, dis_loss:0.33965716138482094
# Epoch:4784, gen_loss: 2.3660465478897095
# --------------------------
# Epoch is 4785
# Number of Batches :  4
# Batch:0
# d_loss :  0.3648112863302231
# g_loss: 2.681204319000244
# Epoch:4785, dis_loss:0.3648112863302231
# Epoch:4785, gen_loss: 2.681204319000244
# Batch:1
# d_loss :  0.3636433035135269
# g_loss: 2.440732955932617
# Epoch:4785, dis_loss:0.364227294921875
# Epoch:4785, gen_loss: 2.5609686374664307
# Batch:2
# d_loss :  0.34153491258621216
# g_loss: 2.234657049179077
# Epoch:4785, dis_loss:0.35666316747665405
# Epoch:4785, gen_loss: 2.452198108037313
# Batch:3
# d_loss :  0.34171605110168457
# g_loss: 1.9413259029388428
# Epoch:4785, dis_loss:0.3529263883829117
# Epoch:4785, gen_loss: 2.3244800567626953
# --------------------------
# Epoch is 4786
# Number of Batches :  4
# Batch:0
# d_loss :  0.34761327505111694
# g_loss: 2.768115282058716
# Epoch:4786, dis_loss:0.34761327505111694
# Epoch:4786, gen_loss: 2.768115282058716
# Batch:1
# d_loss :  0.3384476900100708
# g_loss: 2.3436169624328613
# Epoch:4786, dis_loss:0.34303048253059387
# Epoch:4786, gen_loss: 2.5558661222457886
# Batch:2
# d_loss :  0.34566082060337067
# g_loss: 2.1308860778808594
# Epoch:4786, dis_loss:0.34390726188818616
# Epoch:4786, gen_loss: 2.414206107457479
# Batch:3
# d_loss :  0.33862704038619995
# g_loss: 2.625669479370117
# Epoch:4786, dis_loss:0.3425872065126896
# Epoch:4786, gen_loss: 2.4670719504356384
# --------------------------
# Epoch is 4787
# Number of Batches :  4
# Batch:0
# d_loss :  0.35633037984371185
# g_loss: 2.5673389434814453
# Epoch:4787, dis_loss:0.35633037984371185
# Epoch:4787, gen_loss: 2.5673389434814453
# Batch:1
# d_loss :  0.33257681131362915
# g_loss: 1.8950101137161255
# Epoch:4787, dis_loss:0.3444535955786705
# Epoch:4787, gen_loss: 2.2311745285987854
# Batch:2
# d_loss :  0.34332993626594543
# g_loss: 2.25577712059021
# Epoch:4787, dis_loss:0.34407904247442883
# Epoch:4787, gen_loss: 2.2393753925959268
# Batch:3
# d_loss :  0.34328746795654297
# g_loss: 2.1717653274536133
# Epoch:4787, dis_loss:0.34388114884495735
# Epoch:4787, gen_loss: 2.2224728763103485
# --------------------------
# Epoch is 4788
# Number of Batches :  4
# Batch:0
# d_loss :  0.3481573462486267
# g_loss: 2.0683207511901855
# Epoch:4788, dis_loss:0.3481573462486267
# Epoch:4788, gen_loss: 2.0683207511901855
# Batch:1
# d_loss :  0.33672550320625305
# g_loss: 2.093785285949707
# Epoch:4788, dis_loss:0.3424414247274399
# Epoch:4788, gen_loss: 2.0810530185699463
# Batch:2
# d_loss :  0.3307786285877228
# g_loss: 2.3565473556518555
# Epoch:4788, dis_loss:0.33855382601420086
# Epoch:4788, gen_loss: 2.172884464263916
# Batch:3
# d_loss :  0.343899205327034
# g_loss: 2.1174917221069336
# Epoch:4788, dis_loss:0.33989017084240913
# Epoch:4788, gen_loss: 2.1590362787246704
# --------------------------
# Epoch is 4789
# Number of Batches :  4
# Batch:0
# d_loss :  0.3345721662044525
# g_loss: 2.3395309448242188
# Epoch:4789, dis_loss:0.3345721662044525
# Epoch:4789, gen_loss: 2.3395309448242188
# Batch:1
# d_loss :  0.33984270691871643
# g_loss: 2.308969020843506
# Epoch:4789, dis_loss:0.3372074365615845
# Epoch:4789, gen_loss: 2.3242499828338623
# Batch:2
# d_loss :  0.34003154933452606
# g_loss: 2.6228320598602295
# Epoch:4789, dis_loss:0.3381488074858983
# Epoch:4789, gen_loss: 2.4237773418426514
# Batch:3
# d_loss :  0.3588905334472656
# g_loss: 2.2053256034851074
# Epoch:4789, dis_loss:0.34333423897624016
# Epoch:4789, gen_loss: 2.3691644072532654
# --------------------------
# Epoch is 4790
# Number of Batches :  4
# Batch:0
# d_loss :  0.33310621976852417
# g_loss: 2.5935187339782715
# Epoch:4790, dis_loss:0.33310621976852417
# Epoch:4790, gen_loss: 2.5935187339782715
# Batch:1
# d_loss :  0.3403027206659317
# g_loss: 1.995081901550293
# Epoch:4790, dis_loss:0.33670447021722794
# Epoch:4790, gen_loss: 2.2943003177642822
# Batch:2
# d_loss :  0.34101007878780365
# g_loss: 2.11165714263916
# Epoch:4790, dis_loss:0.3381396730740865
# Epoch:4790, gen_loss: 2.2334192593892417
# Batch:3
# d_loss :  0.3434121906757355
# g_loss: 2.4660277366638184
# Epoch:4790, dis_loss:0.33945780247449875
# Epoch:4790, gen_loss: 2.2915713787078857
# --------------------------
# Epoch is 4791
# Number of Batches :  4
# Batch:0
# d_loss :  0.35962387919425964
# g_loss: 2.1767191886901855
# Epoch:4791, dis_loss:0.35962387919425964
# Epoch:4791, gen_loss: 2.1767191886901855
# Batch:1
# d_loss :  0.3411136269569397
# g_loss: 1.9146232604980469
# Epoch:4791, dis_loss:0.35036875307559967
# Epoch:4791, gen_loss: 2.045671224594116
# Batch:2
# d_loss :  0.3485785573720932
# g_loss: 2.184587240219116
# Epoch:4791, dis_loss:0.34977202117443085
# Epoch:4791, gen_loss: 2.0919765631357827
# Batch:3
# d_loss :  0.3420821726322174
# g_loss: 2.179929733276367
# Epoch:4791, dis_loss:0.3478495590388775
# Epoch:4791, gen_loss: 2.113964855670929
# --------------------------
# Epoch is 4792
# Number of Batches :  4
# Batch:0
# d_loss :  0.3562743365764618
# g_loss: 2.7611794471740723
# Epoch:4792, dis_loss:0.3562743365764618
# Epoch:4792, gen_loss: 2.7611794471740723
# Batch:1
# d_loss :  0.36290302872657776
# g_loss: 2.4758808612823486
# Epoch:4792, dis_loss:0.3595886826515198
# Epoch:4792, gen_loss: 2.6185301542282104
# Batch:2
# d_loss :  0.3521713465452194
# g_loss: 2.1339359283447266
# Epoch:4792, dis_loss:0.357116237282753
# Epoch:4792, gen_loss: 2.4569987456003823
# Batch:3
# d_loss :  0.3442087769508362
# g_loss: 2.3056626319885254
# Epoch:4792, dis_loss:0.3538893721997738
# Epoch:4792, gen_loss: 2.419164717197418
# --------------------------
# Epoch is 4793
# Number of Batches :  4
# Batch:0
# d_loss :  0.337656706571579
# g_loss: 2.4959540367126465
# Epoch:4793, dis_loss:0.337656706571579
# Epoch:4793, gen_loss: 2.4959540367126465
# Batch:1
# d_loss :  0.3455858379602432
# g_loss: 2.1051204204559326
# Epoch:4793, dis_loss:0.3416212722659111
# Epoch:4793, gen_loss: 2.3005372285842896
# Batch:2
# d_loss :  0.33189669251441956
# g_loss: 2.4282305240631104
# Epoch:4793, dis_loss:0.33837974568208057
# Epoch:4793, gen_loss: 2.343101660410563
# Batch:3
# d_loss :  0.3442327678203583
# g_loss: 2.501622200012207
# Epoch:4793, dis_loss:0.33984300121665
# Epoch:4793, gen_loss: 2.382731795310974
# --------------------------
# Epoch is 4794
# Number of Batches :  4
# Batch:0
# d_loss :  0.3618965297937393
# g_loss: 2.8056836128234863
# Epoch:4794, dis_loss:0.3618965297937393
# Epoch:4794, gen_loss: 2.8056836128234863
# Batch:1
# d_loss :  0.34947942197322845
# g_loss: 2.060884952545166
# Epoch:4794, dis_loss:0.3556879758834839
# Epoch:4794, gen_loss: 2.433284282684326
# Batch:2
# d_loss :  0.3303814232349396
# g_loss: 2.4863855838775635
# Epoch:4794, dis_loss:0.3472524583339691
# Epoch:4794, gen_loss: 2.4509847164154053
# Batch:3
# d_loss :  0.3542787432670593
# g_loss: 1.9165292978286743
# Epoch:4794, dis_loss:0.34900902956724167
# Epoch:4794, gen_loss: 2.3173708617687225
# --------------------------
# Epoch is 4795
# Number of Batches :  4
# Batch:0
# d_loss :  0.35821112990379333
# g_loss: 2.4785847663879395
# Epoch:4795, dis_loss:0.35821112990379333
# Epoch:4795, gen_loss: 2.4785847663879395
# Batch:1
# d_loss :  0.33598172664642334
# g_loss: 2.1920166015625
# Epoch:4795, dis_loss:0.34709642827510834
# Epoch:4795, gen_loss: 2.3353006839752197
# Batch:2
# d_loss :  0.33400900661945343
# g_loss: 1.998656988143921
# Epoch:4795, dis_loss:0.34273395438989
# Epoch:4795, gen_loss: 2.22308611869812
# Batch:3
# d_loss :  0.33487026393413544
# g_loss: 2.3436121940612793
# Epoch:4795, dis_loss:0.3407680317759514
# Epoch:4795, gen_loss: 2.25321763753891
# --------------------------
# Epoch is 4796
# Number of Batches :  4
# Batch:0
# d_loss :  0.33611494302749634
# g_loss: 2.3452186584472656
# Epoch:4796, dis_loss:0.33611494302749634
# Epoch:4796, gen_loss: 2.3452186584472656
# Batch:1
# d_loss :  0.3432780057191849
# g_loss: 1.9233036041259766
# Epoch:4796, dis_loss:0.3396964743733406
# Epoch:4796, gen_loss: 2.134261131286621
# Batch:2
# d_loss :  0.33610929548740387
# g_loss: 2.4290690422058105
# Epoch:4796, dis_loss:0.3385007480780284
# Epoch:4796, gen_loss: 2.232530434926351
# Batch:3
# d_loss :  0.33815376460552216
# g_loss: 2.1030831336975098
# Epoch:4796, dis_loss:0.3384140022099018
# Epoch:4796, gen_loss: 2.2001686096191406
# --------------------------
# Epoch is 4797
# Number of Batches :  4
# Batch:0
# d_loss :  0.3551458418369293
# g_loss: 2.3262813091278076
# Epoch:4797, dis_loss:0.3551458418369293
# Epoch:4797, gen_loss: 2.3262813091278076
# Batch:1
# d_loss :  0.3445608615875244
# g_loss: 2.2738802433013916
# Epoch:4797, dis_loss:0.34985335171222687
# Epoch:4797, gen_loss: 2.3000807762145996
# Batch:2
# d_loss :  0.34961554408073425
# g_loss: 2.146087408065796
# Epoch:4797, dis_loss:0.3497740825017293
# Epoch:4797, gen_loss: 2.2487496534983316
# Batch:3
# d_loss :  0.328109011054039
# g_loss: 2.0524117946624756
# Epoch:4797, dis_loss:0.34435781463980675
# Epoch:4797, gen_loss: 2.1996651887893677
# --------------------------
# Epoch is 4798
# Number of Batches :  4
# Batch:0
# d_loss :  0.3546987622976303
# g_loss: 2.6017584800720215
# Epoch:4798, dis_loss:0.3546987622976303
# Epoch:4798, gen_loss: 2.6017584800720215
# Batch:1
# d_loss :  0.3584316223859787
# g_loss: 1.9628376960754395
# Epoch:4798, dis_loss:0.3565651923418045
# Epoch:4798, gen_loss: 2.2822980880737305
# Batch:2
# d_loss :  0.3383544832468033
# g_loss: 2.197329044342041
# Epoch:4798, dis_loss:0.3504949559768041
# Epoch:4798, gen_loss: 2.2539750734965005
# Batch:3
# d_loss :  0.34629809856414795
# g_loss: 2.3987693786621094
# Epoch:4798, dis_loss:0.34944574162364006
# Epoch:4798, gen_loss: 2.290173649787903
# --------------------------
# Epoch is 4799
# Number of Batches :  4
# Batch:0
# d_loss :  0.3602219969034195
# g_loss: 2.0408389568328857
# Epoch:4799, dis_loss:0.3602219969034195
# Epoch:4799, gen_loss: 2.0408389568328857
# Batch:1
# d_loss :  0.3326720893383026
# g_loss: 2.1571826934814453
# Epoch:4799, dis_loss:0.34644704312086105
# Epoch:4799, gen_loss: 2.0990108251571655
# Batch:2
# d_loss :  0.3453114926815033
# g_loss: 2.4856700897216797
# Epoch:4799, dis_loss:0.3460685263077418
# Epoch:4799, gen_loss: 2.2278972466786704
# Batch:3
# d_loss :  0.35642997920513153
# g_loss: 2.1810736656188965
# Epoch:4799, dis_loss:0.34865888953208923
# Epoch:4799, gen_loss: 2.216191351413727
# --------------------------
# Epoch is 4800
# Number of Batches :  4
# Batch:0
# d_loss :  0.33502012491226196
# g_loss: 2.1021275520324707
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:4800, dis_loss:0.33502012491226196
# Epoch:4800, gen_loss: 2.1021275520324707
# Batch:1
# d_loss :  0.32048971951007843
# g_loss: 2.6206133365631104
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:4800, dis_loss:0.3277549222111702
# Epoch:4800, gen_loss: 2.3613704442977905
# Batch:2
# d_loss :  0.3605944365262985
# g_loss: 1.9416810274124146
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:4800, dis_loss:0.33870142698287964
# Epoch:4800, gen_loss: 2.221473972002665
# Batch:3
# d_loss :  0.3550897240638733
# g_loss: 2.2692880630493164
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch:4800, dis_loss:0.34279850125312805
# Epoch:4800, gen_loss: 2.233427494764328
# --------------------------
# Epoch is 4801
# Number of Batches :  4
# Batch:0
# d_loss :  0.34425659477710724
# g_loss: 2.5412344932556152
# Epoch:4801, dis_loss:0.34425659477710724
# Epoch:4801, gen_loss: 2.5412344932556152
# Batch:1
# d_loss :  0.3628992736339569
# g_loss: 1.8983670473098755
# Epoch:4801, dis_loss:0.3535779342055321
# Epoch:4801, gen_loss: 2.2198007702827454
# Batch:2
# d_loss :  0.3323017805814743
# g_loss: 2.429842472076416
# Epoch:4801, dis_loss:0.3464858829975128
# Epoch:4801, gen_loss: 2.2898146708806357
# Batch:3
# d_loss :  0.34058454632759094
# g_loss: 2.47011399269104
# Epoch:4801, dis_loss:0.34501054883003235
# Epoch:4801, gen_loss: 2.3348895013332367
# --------------------------
# Epoch is 4802
# Number of Batches :  4
# Batch:0
# d_loss :  0.35396696627140045
# g_loss: 2.4043102264404297
# Epoch:4802, dis_loss:0.35396696627140045
# Epoch:4802, gen_loss: 2.4043102264404297
# Batch:1
# d_loss :  0.34298281371593475
# g_loss: 2.0306341648101807
# Epoch:4802, dis_loss:0.3484748899936676
# Epoch:4802, gen_loss: 2.217472195625305
# Batch:2
# d_loss :  0.33879801630973816
# g_loss: 2.1946020126342773
# Epoch:4802, dis_loss:0.3452492654323578
# Epoch:4802, gen_loss: 2.2098488012949624
# Batch:3
# d_loss :  0.33302614092826843
# g_loss: 2.4868149757385254
# Epoch:4802, dis_loss:0.34219348430633545
# Epoch:4802, gen_loss: 2.2790903449058533
# --------------------------
# Epoch is 4803
# Number of Batches :  4
# Batch:0
# d_loss :  0.35114315152168274
# g_loss: 2.147928237915039
# Epoch:4803, dis_loss:0.35114315152168274
# Epoch:4803, gen_loss: 2.147928237915039
# Batch:1
# d_loss :  0.32155585289001465
# g_loss: 2.376919746398926
# Epoch:4803, dis_loss:0.3363495022058487
# Epoch:4803, gen_loss: 2.2624239921569824
# Batch:2
# d_loss :  0.34239770472049713
# g_loss: 2.4644553661346436
# Epoch:4803, dis_loss:0.3383655697107315
# Epoch:4803, gen_loss: 2.3297677834828696
# Batch:3
# d_loss :  0.3446448892354965
# g_loss: 2.122753143310547
# Epoch:4803, dis_loss:0.33993539959192276
# Epoch:4803, gen_loss: 2.278014123439789
# --------------------------
# Epoch is 4804
# Number of Batches :  4
# Batch:0
# d_loss :  0.33658725023269653
# g_loss: 2.157914638519287
# Epoch:4804, dis_loss:0.33658725023269653
# Epoch:4804, gen_loss: 2.157914638519287
# Batch:1
# d_loss :  0.3381422311067581
# g_loss: 2.2931063175201416
# Epoch:4804, dis_loss:0.3373647406697273
# Epoch:4804, gen_loss: 2.2255104780197144
# Batch:2
# d_loss :  0.3442729413509369
# g_loss: 2.215210437774658
# Epoch:4804, dis_loss:0.3396674742301305
# Epoch:4804, gen_loss: 2.2220771312713623
# Batch:3
# d_loss :  0.3303847163915634
# g_loss: 2.372722625732422
# Epoch:4804, dis_loss:0.33734678477048874
# Epoch:4804, gen_loss: 2.259738504886627
# --------------------------
# Epoch is 4805
# Number of Batches :  4
# Batch:0
# d_loss :  0.3438616991043091
# g_loss: 2.3364510536193848
# Epoch:4805, dis_loss:0.3438616991043091
# Epoch:4805, gen_loss: 2.3364510536193848
# Batch:1
# d_loss :  0.3358902186155319
# g_loss: 2.114614725112915
# Epoch:4805, dis_loss:0.3398759588599205
# Epoch:4805, gen_loss: 2.22553288936615
# Batch:2
# d_loss :  0.3438195586204529
# g_loss: 2.151700496673584
# Epoch:4805, dis_loss:0.3411904921134313
# Epoch:4805, gen_loss: 2.2009220918019614
# Batch:3
# d_loss :  0.34397512674331665
# g_loss: 2.121716022491455
# Epoch:4805, dis_loss:0.34188665077090263
# Epoch:4805, gen_loss: 2.1811205744743347
# --------------------------
# Epoch is 4806
# Number of Batches :  4
# Batch:0
# d_loss :  0.3350456953048706
# g_loss: 2.847806692123413
# Epoch:4806, dis_loss:0.3350456953048706
# Epoch:4806, gen_loss: 2.847806692123413
# Batch:1
# d_loss :  0.36718660593032837
# g_loss: 2.182344436645508
# Epoch:4806, dis_loss:0.3511161506175995
# Epoch:4806, gen_loss: 2.5150755643844604
# Batch:2
# d_loss :  0.3338007479906082
# g_loss: 2.274272918701172
# Epoch:4806, dis_loss:0.34534434974193573
# Epoch:4806, gen_loss: 2.4348080158233643
# Batch:3
# d_loss :  0.3566321134567261
# g_loss: 2.109614610671997
# Epoch:4806, dis_loss:0.3481662906706333
# Epoch:4806, gen_loss: 2.3535096645355225
# --------------------------
# Epoch is 4807
# Number of Batches :  4
# Batch:0
# d_loss :  0.3349335491657257
# g_loss: 2.341475009918213
# Epoch:4807, dis_loss:0.3349335491657257
# Epoch:4807, gen_loss: 2.341475009918213
# Batch:1
# d_loss :  0.33223359286785126
# g_loss: 2.1259360313415527
# Epoch:4807, dis_loss:0.3335835710167885
# Epoch:4807, gen_loss: 2.233705520629883
# Batch:2
# d_loss :  0.34114982187747955
# g_loss: 2.2451796531677246
# Epoch:4807, dis_loss:0.33610565463701886
# Epoch:4807, gen_loss: 2.23753023147583
# Batch:3
# d_loss :  0.3498416841030121
# g_loss: 1.985633134841919
# Epoch:4807, dis_loss:0.33953966200351715
# Epoch:4807, gen_loss: 2.1745559573173523
# --------------------------
# Epoch is 4808
# Number of Batches :  4
# Batch:0
# d_loss :  0.34660640358924866
# g_loss: 2.241400718688965
# Epoch:4808, dis_loss:0.34660640358924866
# Epoch:4808, gen_loss: 2.241400718688965
# Batch:1
# d_loss :  0.3252808749675751
# g_loss: 2.245915412902832
# Epoch:4808, dis_loss:0.33594363927841187
# Epoch:4808, gen_loss: 2.2436580657958984
# Batch:2
# d_loss :  0.34897512197494507
# g_loss: 2.0994439125061035
# Epoch:4808, dis_loss:0.3402874668439229
# Epoch:4808, gen_loss: 2.195586681365967
# Batch:3
# d_loss :  0.3390291631221771
# g_loss: 2.3247251510620117
# Epoch:4808, dis_loss:0.3399728909134865
# Epoch:4808, gen_loss: 2.227871298789978
# --------------------------
# Epoch is 4809
# Number of Batches :  4
# Batch:0
# d_loss :  0.3350376784801483
# g_loss: 2.2340140342712402
# Epoch:4809, dis_loss:0.3350376784801483
# Epoch:4809, gen_loss: 2.2340140342712402
# Batch:1
# d_loss :  0.3213804364204407
# g_loss: 2.2180683612823486
# Epoch:4809, dis_loss:0.3282090574502945
# Epoch:4809, gen_loss: 2.2260411977767944
# Batch:2
# d_loss :  0.3315364420413971
# g_loss: 2.316025972366333
# Epoch:4809, dis_loss:0.3293181856473287
# Epoch:4809, gen_loss: 2.256036122639974
# Batch:3
# d_loss :  0.3407604396343231
# g_loss: 2.21240234375
# Epoch:4809, dis_loss:0.3321787491440773
# Epoch:4809, gen_loss: 2.2451276779174805
# --------------------------
# Epoch is 4810
# Number of Batches :  4
# Batch:0
# d_loss :  0.35141676664352417
# g_loss: 2.279520034790039
# Epoch:4810, dis_loss:0.35141676664352417
# Epoch:4810, gen_loss: 2.279520034790039
# Batch:1
# d_loss :  0.3391873836517334
# g_loss: 2.0888826847076416
# Epoch:4810, dis_loss:0.3453020751476288
# Epoch:4810, gen_loss: 2.1842013597488403
# Batch:2
# d_loss :  0.34532175958156586
# g_loss: 2.3188676834106445
# Epoch:4810, dis_loss:0.3453086366256078
# Epoch:4810, gen_loss: 2.229090134302775
# Batch:3
# d_loss :  0.3367539495229721
# g_loss: 2.2445406913757324
# Epoch:4810, dis_loss:0.3431699648499489
# Epoch:4810, gen_loss: 2.2329527735710144
# --------------------------
# Epoch is 4811
# Number of Batches :  4
# Batch:0
# d_loss :  0.35457974672317505
# g_loss: 2.377572536468506
# Epoch:4811, dis_loss:0.35457974672317505
# Epoch:4811, gen_loss: 2.377572536468506
# Batch:1
# d_loss :  0.3486047089099884
# g_loss: 2.0173842906951904
# Epoch:4811, dis_loss:0.3515922278165817
# Epoch:4811, gen_loss: 2.197478413581848
# Batch:2
# d_loss :  0.3446331024169922
# g_loss: 2.2424495220184326
# Epoch:4811, dis_loss:0.3492725193500519
# Epoch:4811, gen_loss: 2.2124687830607095
# Batch:3
# d_loss :  0.34247198700904846
# g_loss: 2.266648769378662
# Epoch:4811, dis_loss:0.347572386264801
# Epoch:4811, gen_loss: 2.2260137796401978
# --------------------------
# Epoch is 4812
# Number of Batches :  4
# Batch:0
# d_loss :  0.34441208839416504
# g_loss: 2.267102003097534
# Epoch:4812, dis_loss:0.34441208839416504
# Epoch:4812, gen_loss: 2.267102003097534
# Batch:1
# d_loss :  0.3252752423286438
# g_loss: 2.12520170211792
# Epoch:4812, dis_loss:0.3348436653614044
# Epoch:4812, gen_loss: 2.196151852607727
# Batch:2
# d_loss :  0.332149475812912
# g_loss: 2.3016839027404785
# Epoch:4812, dis_loss:0.3339456021785736
# Epoch:4812, gen_loss: 2.2313292026519775
# Batch:3
# d_loss :  0.33060330152511597
# g_loss: 2.1243484020233154
# Epoch:4812, dis_loss:0.3331100270152092
# Epoch:4812, gen_loss: 2.204584002494812
# --------------------------
# Epoch is 4813
# Number of Batches :  4
# Batch:0
# d_loss :  0.34119755029678345
# g_loss: 2.247570276260376
# Epoch:4813, dis_loss:0.34119755029678345
# Epoch:4813, gen_loss: 2.247570276260376
# Batch:1
# d_loss :  0.3539936691522598
# g_loss: 1.9567559957504272
# Epoch:4813, dis_loss:0.34759560972452164
# Epoch:4813, gen_loss: 2.1021631360054016
# Batch:2
# d_loss :  0.33781224489212036
# g_loss: 2.236396074295044
# Epoch:4813, dis_loss:0.3443344881137212
# Epoch:4813, gen_loss: 2.1469074487686157
# Batch:3
# d_loss :  0.32745930552482605
# g_loss: 2.3740036487579346
# Epoch:4813, dis_loss:0.3401156924664974
# Epoch:4813, gen_loss: 2.2036814987659454
# --------------------------
# Epoch is 4814
# Number of Batches :  4
# Batch:0
# d_loss :  0.3511720895767212
# g_loss: 2.1718552112579346
# Epoch:4814, dis_loss:0.3511720895767212
# Epoch:4814, gen_loss: 2.1718552112579346
# Batch:1
# d_loss :  0.3267108052968979
# g_loss: 2.2039711475372314
# Epoch:4814, dis_loss:0.33894144743680954
# Epoch:4814, gen_loss: 2.187913179397583
# Batch:2
# d_loss :  0.3307834565639496
# g_loss: 2.3041224479675293
# Epoch:4814, dis_loss:0.3362221171458562
# Epoch:4814, gen_loss: 2.226649602254232
# Batch:3
# d_loss :  0.33401642739772797
# g_loss: 2.294482469558716
# Epoch:4814, dis_loss:0.33567069470882416
# Epoch:4814, gen_loss: 2.243607819080353
# --------------------------
# Epoch is 4815
# Number of Batches :  4
# Batch:0
# d_loss :  0.3376702517271042
# g_loss: 2.2726454734802246
# Epoch:4815, dis_loss:0.3376702517271042
# Epoch:4815, gen_loss: 2.2726454734802246
# Batch:1
# d_loss :  0.34121423959732056
# g_loss: 2.0828778743743896
# Epoch:4815, dis_loss:0.33944224566221237
# Epoch:4815, gen_loss: 2.177761673927307
# Batch:2
# d_loss :  0.3434162437915802
# g_loss: 2.103947162628174
# Epoch:4815, dis_loss:0.34076691170533496
# Epoch:4815, gen_loss: 2.153156836827596
# Batch:3
# d_loss :  0.33567626774311066
# g_loss: 2.287642240524292
# Epoch:4815, dis_loss:0.3394942507147789
# Epoch:4815, gen_loss: 2.18677818775177
# --------------------------
# Epoch is 4816
# Number of Batches :  4
# Batch:0
# d_loss :  0.3416070193052292
# g_loss: 2.2885165214538574
# Epoch:4816, dis_loss:0.3416070193052292
# Epoch:4816, gen_loss: 2.2885165214538574
# Batch:1
# d_loss :  0.33415132761001587
# g_loss: 2.1315064430236816
# Epoch:4816, dis_loss:0.33787917345762253
# Epoch:4816, gen_loss: 2.2100114822387695
# Batch:2
# d_loss :  0.31613028049468994
# g_loss: 2.411250591278076
# Epoch:4816, dis_loss:0.33062954246997833
# Epoch:4816, gen_loss: 2.2770911852518716
# Batch:3
# d_loss :  0.3388647884130478
# g_loss: 2.264927864074707
# Epoch:4816, dis_loss:0.3326883539557457
# Epoch:4816, gen_loss: 2.2740503549575806
# --------------------------
# Epoch is 4817
# Number of Batches :  4
# Batch:0
# d_loss :  0.335954949259758
# g_loss: 2.3246231079101562
# Epoch:4817, dis_loss:0.335954949259758
# Epoch:4817, gen_loss: 2.3246231079101562
# Batch:1
# d_loss :  0.33276911079883575
# g_loss: 2.225085735321045
# Epoch:4817, dis_loss:0.3343620300292969
# Epoch:4817, gen_loss: 2.2748544216156006
# Batch:2
# d_loss :  0.34306828677654266
# g_loss: 2.210867404937744
# Epoch:4817, dis_loss:0.33726411561171216
# Epoch:4817, gen_loss: 2.253525416056315
# Batch:3
# d_loss :  0.34094947576522827
# g_loss: 2.252464532852173
# Epoch:4817, dis_loss:0.33818545565009117
# Epoch:4817, gen_loss: 2.2532601952552795
# --------------------------
# Epoch is 4818
# Number of Batches :  4
# Batch:0
# d_loss :  0.3565773665904999
# g_loss: 2.3017685413360596
# Epoch:4818, dis_loss:0.3565773665904999
# Epoch:4818, gen_loss: 2.3017685413360596
# Batch:1
# d_loss :  0.34532415866851807
# g_loss: 2.064530372619629
# Epoch:4818, dis_loss:0.35095076262950897
# Epoch:4818, gen_loss: 2.1831494569778442
# Batch:2
# d_loss :  0.339814230799675
# g_loss: 2.2178139686584473
# Epoch:4818, dis_loss:0.34723858535289764
# Epoch:4818, gen_loss: 2.194704294204712
# Batch:3
# d_loss :  0.33801349997520447
# g_loss: 2.1869895458221436
# Epoch:4818, dis_loss:0.34493231400847435
# Epoch:4818, gen_loss: 2.19277560710907
# --------------------------
# Epoch is 4819
# Number of Batches :  4
# Batch:0
# d_loss :  0.3439815938472748
# g_loss: 2.4032280445098877
# Epoch:4819, dis_loss:0.3439815938472748
# Epoch:4819, gen_loss: 2.4032280445098877
# Batch:1
# d_loss :  0.33209429681301117
# g_loss: 2.230865716934204
# Epoch:4819, dis_loss:0.338037945330143
# Epoch:4819, gen_loss: 2.317046880722046
# Batch:2
# d_loss :  0.3264973908662796
# g_loss: 2.3133182525634766
# Epoch:4819, dis_loss:0.33419109384218854
# Epoch:4819, gen_loss: 2.3158040046691895
# Batch:3
# d_loss :  0.3419269621372223
# g_loss: 2.3424224853515625
# Epoch:4819, dis_loss:0.33612506091594696
# Epoch:4819, gen_loss: 2.3224586248397827
# --------------------------
# Epoch is 4820
# Number of Batches :  4
# Batch:0
# d_loss :  0.3380352258682251
# g_loss: 2.266282081604004
# Epoch:4820, dis_loss:0.3380352258682251
# Epoch:4820, gen_loss: 2.266282081604004
# Batch:1
# d_loss :  0.3406004458665848
# g_loss: 2.1426024436950684
# Epoch:4820, dis_loss:0.33931783586740494
# Epoch:4820, gen_loss: 2.204442262649536
# Batch:2
# d_loss :  0.3380791246891022
# g_loss: 2.287419319152832
# Epoch:4820, dis_loss:0.338904932141304
# Epoch:4820, gen_loss: 2.2321012814839682
# Batch:3
# d_loss :  0.33158358931541443
# g_loss: 2.322042942047119
# Epoch:4820, dis_loss:0.3370745964348316
# Epoch:4820, gen_loss: 2.254586696624756
# --------------------------
# Epoch is 4821
# Number of Batches :  4
# Batch:0
# d_loss :  0.34496672451496124
# g_loss: 2.215913772583008
# Epoch:4821, dis_loss:0.34496672451496124
# Epoch:4821, gen_loss: 2.215913772583008
# Batch:1
# d_loss :  0.33759836852550507
# g_loss: 2.1734302043914795
# Epoch:4821, dis_loss:0.34128254652023315
# Epoch:4821, gen_loss: 2.1946719884872437
# Batch:2
# d_loss :  0.3445855677127838
# g_loss: 2.149409055709839
# Epoch:4821, dis_loss:0.3423835535844167
# Epoch:4821, gen_loss: 2.179584344228109
# Batch:3
# d_loss :  0.3394322395324707
# g_loss: 2.2540500164031982
# Epoch:4821, dis_loss:0.3416457250714302
# Epoch:4821, gen_loss: 2.198200762271881
# --------------------------
# Epoch is 4822
# Number of Batches :  4
# Batch:0
# d_loss :  0.34047143161296844
# g_loss: 2.136899471282959
# Epoch:4822, dis_loss:0.34047143161296844
# Epoch:4822, gen_loss: 2.136899471282959
# Batch:1
# d_loss :  0.3303866684436798
# g_loss: 2.2966971397399902
# Epoch:4822, dis_loss:0.3354290500283241
# Epoch:4822, gen_loss: 2.2167983055114746
# Batch:2
# d_loss :  0.34961704909801483
# g_loss: 2.1119651794433594
# Epoch:4822, dis_loss:0.3401583830515544
# Epoch:4822, gen_loss: 2.181853930155436
# Batch:3
# d_loss :  0.32929232716560364
# g_loss: 2.218128204345703
# Epoch:4822, dis_loss:0.3374418690800667
# Epoch:4822, gen_loss: 2.190922498703003
# --------------------------
# Epoch is 4823
# Number of Batches :  4
# Batch:0
# d_loss :  0.33728691935539246
# g_loss: 2.179500102996826
# Epoch:4823, dis_loss:0.33728691935539246
# Epoch:4823, gen_loss: 2.179500102996826
# Batch:1
# d_loss :  0.3230607360601425
# g_loss: 2.1643004417419434
# Epoch:4823, dis_loss:0.3301738277077675
# Epoch:4823, gen_loss: 2.1719002723693848
# Batch:2
# d_loss :  0.3373631238937378
# g_loss: 2.0857996940612793
# Epoch:4823, dis_loss:0.33257025976975757
# Epoch:4823, gen_loss: 2.143200079600016
# Batch:3
# d_loss :  0.34818224608898163
# g_loss: 2.2906336784362793
# Epoch:4823, dis_loss:0.3364732563495636
# Epoch:4823, gen_loss: 2.180058479309082
# --------------------------
# Epoch is 4824
# Number of Batches :  4
# Batch:0
# d_loss :  0.3465479016304016
# g_loss: 2.4455080032348633
# Epoch:4824, dis_loss:0.3465479016304016
# Epoch:4824, gen_loss: 2.4455080032348633
# Batch:1
# d_loss :  0.3415887951850891
# g_loss: 2.169083595275879
# Epoch:4824, dis_loss:0.34406834840774536
# Epoch:4824, gen_loss: 2.307295799255371
# Batch:2
# d_loss :  0.3421117514371872
# g_loss: 2.310100555419922
# Epoch:4824, dis_loss:0.3434161494175593
# Epoch:4824, gen_loss: 2.308230717976888
# Batch:3
# d_loss :  0.33660659193992615
# g_loss: 2.1586802005767822
# Epoch:4824, dis_loss:0.341713760048151
# Epoch:4824, gen_loss: 2.2708430886268616
# --------------------------
# Epoch is 4825
# Number of Batches :  4
# Batch:0
# d_loss :  0.3378213196992874
# g_loss: 2.6241416931152344
# Epoch:4825, dis_loss:0.3378213196992874
# Epoch:4825, gen_loss: 2.6241416931152344
# Batch:1
# d_loss :  0.3412724435329437
# g_loss: 2.3405022621154785
# Epoch:4825, dis_loss:0.33954688161611557
# Epoch:4825, gen_loss: 2.4823219776153564
# Batch:2
# d_loss :  0.32750141620635986
# g_loss: 2.306048631668091
# Epoch:4825, dis_loss:0.33553172647953033
# Epoch:4825, gen_loss: 2.4235641956329346
# Batch:3
# d_loss :  0.334580659866333
# g_loss: 1.9209117889404297
# Epoch:4825, dis_loss:0.335293959826231
# Epoch:4825, gen_loss: 2.2979010939598083
# --------------------------
# Epoch is 4826
# Number of Batches :  4
# Batch:0
# d_loss :  0.32931268215179443
# g_loss: 2.6497368812561035
# Epoch:4826, dis_loss:0.32931268215179443
# Epoch:4826, gen_loss: 2.6497368812561035
# Batch:1
# d_loss :  0.34065935015678406
# g_loss: 2.0820648670196533
# Epoch:4826, dis_loss:0.33498601615428925
# Epoch:4826, gen_loss: 2.3659008741378784
# Batch:2
# d_loss :  0.33113692700862885
# g_loss: 2.3794660568237305
# Epoch:4826, dis_loss:0.3337029864390691
# Epoch:4826, gen_loss: 2.370422601699829
# Batch:3
# d_loss :  0.346829429268837
# g_loss: 2.194230079650879
# Epoch:4826, dis_loss:0.3369845971465111
# Epoch:4826, gen_loss: 2.3263744711875916
# --------------------------
# Epoch is 4827
# Number of Batches :  4
# Batch:0
# d_loss :  0.3519437462091446
# g_loss: 2.1954338550567627
# Epoch:4827, dis_loss:0.3519437462091446
# Epoch:4827, gen_loss: 2.1954338550567627
# Batch:1
# d_loss :  0.32115472853183746
# g_loss: 2.482452392578125
# Epoch:4827, dis_loss:0.33654923737049103
# Epoch:4827, gen_loss: 2.338943123817444
# Batch:2
# d_loss :  0.34949611127376556
# g_loss: 2.356292724609375
# Epoch:4827, dis_loss:0.3408648620049159
# Epoch:4827, gen_loss: 2.344726324081421
# Batch:3
# d_loss :  0.3535890579223633
# g_loss: 2.2596278190612793
# Epoch:4827, dis_loss:0.3440459109842777
# Epoch:4827, gen_loss: 2.3234516978263855
# --------------------------
# Epoch is 4828
# Number of Batches :  4
# Batch:0
# d_loss :  0.3512948155403137
# g_loss: 2.343177318572998
# Epoch:4828, dis_loss:0.3512948155403137
# Epoch:4828, gen_loss: 2.343177318572998
# Batch:1
# d_loss :  0.34366315603256226
# g_loss: 1.8440359830856323
# Epoch:4828, dis_loss:0.347478985786438
# Epoch:4828, gen_loss: 2.093606650829315
# Batch:2
# d_loss :  0.3452198654413223
# g_loss: 2.6073594093322754
# Epoch:4828, dis_loss:0.3467259456713994
# Epoch:4828, gen_loss: 2.2648575703303018
# Batch:3
# d_loss :  0.350416362285614
# g_loss: 2.3502893447875977
# Epoch:4828, dis_loss:0.3476485498249531
# Epoch:4828, gen_loss: 2.286215513944626
# --------------------------
# Epoch is 4829
# Number of Batches :  4
# Batch:0
# d_loss :  0.3374570161104202
# g_loss: 2.3417201042175293
# Epoch:4829, dis_loss:0.3374570161104202
# Epoch:4829, gen_loss: 2.3417201042175293
# Batch:1
# d_loss :  0.3439030945301056
# g_loss: 1.9540928602218628
# Epoch:4829, dis_loss:0.3406800553202629
# Epoch:4829, gen_loss: 2.147906482219696
# Batch:2
# d_loss :  0.3404102623462677
# g_loss: 2.1507210731506348
# Epoch:4829, dis_loss:0.34059012432893115
# Epoch:4829, gen_loss: 2.1488446791966758
# Batch:3
# d_loss :  0.3298074007034302
# g_loss: 2.230140447616577
# Epoch:4829, dis_loss:0.3378944434225559
# Epoch:4829, gen_loss: 2.169168621301651
# --------------------------
# Epoch is 4830
# Number of Batches :  4
# Batch:0
# d_loss :  0.3315064460039139
# g_loss: 2.2711822986602783
# Epoch:4830, dis_loss:0.3315064460039139
# Epoch:4830, gen_loss: 2.2711822986602783
# Batch:1
# d_loss :  0.3387686759233475
# g_loss: 2.2390687465667725
# Epoch:4830, dis_loss:0.3351375609636307
# Epoch:4830, gen_loss: 2.2551255226135254
# Batch:2
# d_loss :  0.34807854890823364
# g_loss: 2.5160179138183594
# Epoch:4830, dis_loss:0.33945122361183167
# Epoch:4830, gen_loss: 2.3420896530151367
# Batch:3
# d_loss :  0.34064218401908875
# g_loss: 2.2031033039093018
# Epoch:4830, dis_loss:0.33974896371364594
# Epoch:4830, gen_loss: 2.307343065738678
# --------------------------
# Epoch is 4831
# Number of Batches :  4
# Batch:0
# d_loss :  0.34695491194725037
# g_loss: 2.63531494140625
# Epoch:4831, dis_loss:0.34695491194725037
# Epoch:4831, gen_loss: 2.63531494140625
# Batch:1
# d_loss :  0.33534814417362213
# g_loss: 2.3655519485473633
# Epoch:4831, dis_loss:0.34115152806043625
# Epoch:4831, gen_loss: 2.5004334449768066
# Batch:2
# d_loss :  0.3531712144613266
# g_loss: 2.397397518157959
# Epoch:4831, dis_loss:0.34515809019406635
# Epoch:4831, gen_loss: 2.466088136037191
# Batch:3
# d_loss :  0.34616218507289886
# g_loss: 1.9950571060180664
# Epoch:4831, dis_loss:0.3454091139137745
# Epoch:4831, gen_loss: 2.3483303785324097
# --------------------------
# Epoch is 4832
# Number of Batches :  4
# Batch:0
# d_loss :  0.35047924518585205
# g_loss: 1.9918934106826782
# Epoch:4832, dis_loss:0.35047924518585205
# Epoch:4832, gen_loss: 1.9918934106826782
# Batch:1
# d_loss :  0.35553862154483795
# g_loss: 2.6236462593078613
# Epoch:4832, dis_loss:0.353008933365345
# Epoch:4832, gen_loss: 2.3077698349952698
# Batch:2
# d_loss :  0.3671877682209015
# g_loss: 1.9144366979599
# Epoch:4832, dis_loss:0.3577352116505305
# Epoch:4832, gen_loss: 2.176658789316813
# Batch:3
# d_loss :  0.3437197208404541
# g_loss: 2.995403289794922
# Epoch:4832, dis_loss:0.3542313389480114
# Epoch:4832, gen_loss: 2.3813449144363403
# --------------------------
# Epoch is 4833
# Number of Batches :  4
# Batch:0
# d_loss :  0.3476845622062683
# g_loss: 2.3706040382385254
# Epoch:4833, dis_loss:0.3476845622062683
# Epoch:4833, gen_loss: 2.3706040382385254
# Batch:1
# d_loss :  0.335666760802269
# g_loss: 1.9812352657318115
# Epoch:4833, dis_loss:0.34167566150426865
# Epoch:4833, gen_loss: 2.1759196519851685
# Batch:2
# d_loss :  0.3596419095993042
# g_loss: 3.616603374481201
# Epoch:4833, dis_loss:0.3476644108692805
# Epoch:4833, gen_loss: 2.656147559483846
# Batch:3
# d_loss :  0.43295998871326447
# g_loss: 2.542156934738159
# Epoch:4833, dis_loss:0.3689883053302765
# Epoch:4833, gen_loss: 2.6276499032974243
# --------------------------
# Epoch is 4834
# Number of Batches :  4
# Batch:0
# d_loss :  0.3323505371809006
# g_loss: 2.269798755645752
# Epoch:4834, dis_loss:0.3323505371809006
# Epoch:4834, gen_loss: 2.269798755645752
# Batch:1
# d_loss :  0.3422415554523468
# g_loss: 2.2008986473083496
# Epoch:4834, dis_loss:0.3372960463166237
# Epoch:4834, gen_loss: 2.235348701477051
# Batch:2
# d_loss :  0.33040574193000793
# g_loss: 2.345231056213379
# Epoch:4834, dis_loss:0.33499927818775177
# Epoch:4834, gen_loss: 2.2719761530558267
# Batch:3
# d_loss :  0.3360036015510559
# g_loss: 2.201597213745117
# Epoch:4834, dis_loss:0.3352503590285778
# Epoch:4834, gen_loss: 2.2543814182281494
# --------------------------
# Epoch is 4835
# Number of Batches :  4
# Batch:0
# d_loss :  0.3534903973340988
# g_loss: 1.9771547317504883
# Epoch:4835, dis_loss:0.3534903973340988
# Epoch:4835, gen_loss: 1.9771547317504883
# Batch:1
# d_loss :  0.32873116433620453
# g_loss: 2.1780829429626465
# Epoch:4835, dis_loss:0.3411107808351517
# Epoch:4835, gen_loss: 2.0776188373565674
# Batch:2
# d_loss :  0.32912424206733704
# g_loss: 2.044074773788452
# Epoch:4835, dis_loss:0.3371152679125468
# Epoch:4835, gen_loss: 2.0664374828338623
# Batch:3
# d_loss :  0.3338281214237213
# g_loss: 2.1127147674560547
# Epoch:4835, dis_loss:0.3362934812903404
# Epoch:4835, gen_loss: 2.0780068039894104
# --------------------------
# Epoch is 4836
# Number of Batches :  4
# Batch:0
# d_loss :  0.33646194636821747
# g_loss: 2.098264217376709
# Epoch:4836, dis_loss:0.33646194636821747
# Epoch:4836, gen_loss: 2.098264217376709
# Batch:1
# d_loss :  0.32005803287029266
# g_loss: 2.259092330932617
# Epoch:4836, dis_loss:0.32825998961925507
# Epoch:4836, gen_loss: 2.178678274154663
# Batch:2
# d_loss :  0.34331338107585907
# g_loss: 2.1662917137145996
# Epoch:4836, dis_loss:0.3332777867714564
# Epoch:4836, gen_loss: 2.174549420674642
# Batch:3
# d_loss :  0.33245792984962463
# g_loss: 2.235538959503174
# Epoch:4836, dis_loss:0.33307282254099846
# Epoch:4836, gen_loss: 2.189796805381775
# --------------------------
# Epoch is 4837
# Number of Batches :  4
# Batch:0
# d_loss :  0.3384094685316086
# g_loss: 2.1594998836517334
# Epoch:4837, dis_loss:0.3384094685316086
# Epoch:4837, gen_loss: 2.1594998836517334
# Batch:1
# d_loss :  0.32337379455566406
# g_loss: 2.2580485343933105
# Epoch:4837, dis_loss:0.3308916315436363
# Epoch:4837, gen_loss: 2.208774209022522
# Batch:2
# d_loss :  0.33486825227737427
# g_loss: 2.3961546421051025
# Epoch:4837, dis_loss:0.33221717178821564
# Epoch:4837, gen_loss: 2.2712343533833823
# Batch:3
# d_loss :  0.34742143750190735
# g_loss: 2.182112216949463
# Epoch:4837, dis_loss:0.33601823821663857
# Epoch:4837, gen_loss: 2.2489538192749023
# --------------------------
# Epoch is 4838
# Number of Batches :  4
# Batch:0
# d_loss :  0.32648037374019623
# g_loss: 2.2587482929229736
# Epoch:4838, dis_loss:0.32648037374019623
# Epoch:4838, gen_loss: 2.2587482929229736
# Batch:1
# d_loss :  0.34934236109256744
# g_loss: 1.772470474243164
# Epoch:4838, dis_loss:0.33791136741638184
# Epoch:4838, gen_loss: 2.015609383583069
# Batch:2
# d_loss :  0.36017225682735443
# g_loss: 3.287139415740967
# Epoch:4838, dis_loss:0.34533166388670605
# Epoch:4838, gen_loss: 2.4394527276357016
# Batch:3
# d_loss :  0.38645099103450775
# g_loss: 2.1839940547943115
# Epoch:4838, dis_loss:0.35561149567365646
# Epoch:4838, gen_loss: 2.375588059425354
# --------------------------
# Epoch is 4839
# Number of Batches :  4
# Batch:0
# d_loss :  0.3477455824613571
# g_loss: 1.965000867843628
# Epoch:4839, dis_loss:0.3477455824613571
# Epoch:4839, gen_loss: 1.965000867843628
# Batch:1
# d_loss :  0.35189089179039
# g_loss: 2.3559916019439697
# Epoch:4839, dis_loss:0.34981823712587357
# Epoch:4839, gen_loss: 2.160496234893799
# Batch:2
# d_loss :  0.33227553963661194
# g_loss: 2.5625510215759277
# Epoch:4839, dis_loss:0.3439706712961197
# Epoch:4839, gen_loss: 2.2945144971211753
# Batch:3
# d_loss :  0.34739671647548676
# g_loss: 2.25042724609375
# Epoch:4839, dis_loss:0.34482718259096146
# Epoch:4839, gen_loss: 2.283492684364319
# --------------------------
# Epoch is 4840
# Number of Batches :  4
# Batch:0
# d_loss :  0.33045952022075653
# g_loss: 2.4452052116394043
# Epoch:4840, dis_loss:0.33045952022075653
# Epoch:4840, gen_loss: 2.4452052116394043
# Batch:1
# d_loss :  0.3335238993167877
# g_loss: 2.0944650173187256
# Epoch:4840, dis_loss:0.3319917097687721
# Epoch:4840, gen_loss: 2.269835114479065
# Batch:2
# d_loss :  0.3321972042322159
# g_loss: 2.3896639347076416
# Epoch:4840, dis_loss:0.33206020792325336
# Epoch:4840, gen_loss: 2.3097780545552573
# Batch:3
# d_loss :  0.3383078873157501
# g_loss: 2.2430880069732666
# Epoch:4840, dis_loss:0.33362212777137756
# Epoch:4840, gen_loss: 2.2931055426597595
# --------------------------
# Epoch is 4841
# Number of Batches :  4
# Batch:0
# d_loss :  0.33760271966457367
# g_loss: 2.1785888671875
# Epoch:4841, dis_loss:0.33760271966457367
# Epoch:4841, gen_loss: 2.1785888671875
# Batch:1
# d_loss :  0.3436724841594696
# g_loss: 2.3141098022460938
# Epoch:4841, dis_loss:0.34063760191202164
# Epoch:4841, gen_loss: 2.246349334716797
# Batch:2
# d_loss :  0.34689606726169586
# g_loss: 2.2401301860809326
# Epoch:4841, dis_loss:0.3427237570285797
# Epoch:4841, gen_loss: 2.244276285171509
# Batch:3
# d_loss :  0.3428064435720444
# g_loss: 1.9147603511810303
# Epoch:4841, dis_loss:0.3427444286644459
# Epoch:4841, gen_loss: 2.161897301673889
# --------------------------
# Epoch is 4842
# Number of Batches :  4
# Batch:0
# d_loss :  0.3373743146657944
# g_loss: 3.0872621536254883
# Epoch:4842, dis_loss:0.3373743146657944
# Epoch:4842, gen_loss: 3.0872621536254883
# Batch:1
# d_loss :  0.3696501851081848
# g_loss: 1.9142757654190063
# Epoch:4842, dis_loss:0.3535122498869896
# Epoch:4842, gen_loss: 2.5007689595222473
# Batch:2
# d_loss :  0.3332495391368866
# g_loss: 2.385983467102051
# Epoch:4842, dis_loss:0.3467580129702886
# Epoch:4842, gen_loss: 2.462507128715515
# Batch:3
# d_loss :  0.3129703253507614
# g_loss: 2.6570239067077637
# Epoch:4842, dis_loss:0.3383110910654068
# Epoch:4842, gen_loss: 2.5111363232135773
# --------------------------
# Epoch is 4843
# Number of Batches :  4
# Batch:0
# d_loss :  0.3488011658191681
# g_loss: 1.9838922023773193
# Epoch:4843, dis_loss:0.3488011658191681
# Epoch:4843, gen_loss: 1.9838922023773193
# Batch:1
# d_loss :  0.3332740366458893
# g_loss: 2.231368064880371
# Epoch:4843, dis_loss:0.3410376012325287
# Epoch:4843, gen_loss: 2.107630133628845
# Batch:2
# d_loss :  0.3345254063606262
# g_loss: 2.485093116760254
# Epoch:4843, dis_loss:0.3388668696085612
# Epoch:4843, gen_loss: 2.2334511280059814
# Batch:3
# d_loss :  0.3530081659555435
# g_loss: 2.521674156188965
# Epoch:4843, dis_loss:0.3424021936953068
# Epoch:4843, gen_loss: 2.3055068850517273
# --------------------------
# Epoch is 4844
# Number of Batches :  4
# Batch:0
# d_loss :  0.33600547909736633
# g_loss: 2.0662763118743896
# Epoch:4844, dis_loss:0.33600547909736633
# Epoch:4844, gen_loss: 2.0662763118743896
# Batch:1
# d_loss :  0.3415758013725281
# g_loss: 2.0889339447021484
# Epoch:4844, dis_loss:0.3387906402349472
# Epoch:4844, gen_loss: 2.077605128288269
# Batch:2
# d_loss :  0.3498656153678894
# g_loss: 2.4247071743011475
# Epoch:4844, dis_loss:0.3424822986125946
# Epoch:4844, gen_loss: 2.193305810292562
# Batch:3
# d_loss :  0.3500370979309082
# g_loss: 2.2429277896881104
# Epoch:4844, dis_loss:0.344370998442173
# Epoch:4844, gen_loss: 2.205711305141449
# --------------------------
# Epoch is 4845
# Number of Batches :  4
# Batch:0
# d_loss :  0.3380001187324524
# g_loss: 1.8687751293182373
# Epoch:4845, dis_loss:0.3380001187324524
# Epoch:4845, gen_loss: 1.8687751293182373
# Batch:1
# d_loss :  0.34137122333049774
# g_loss: 2.2439823150634766
# Epoch:4845, dis_loss:0.33968567103147507
# Epoch:4845, gen_loss: 2.056378722190857
# Batch:2
# d_loss :  0.332333043217659
# g_loss: 2.404402017593384
# Epoch:4845, dis_loss:0.3372347950935364
# Epoch:4845, gen_loss: 2.1723864873250327
# Batch:3
# d_loss :  0.3418324738740921
# g_loss: 1.993603229522705
# Epoch:4845, dis_loss:0.3383842147886753
# Epoch:4845, gen_loss: 2.1276906728744507
# --------------------------
# Epoch is 4846
# Number of Batches :  4
# Batch:0
# d_loss :  0.35943977534770966
# g_loss: 2.796085834503174
# Epoch:4846, dis_loss:0.35943977534770966
# Epoch:4846, gen_loss: 2.796085834503174
# Batch:1
# d_loss :  0.36893948912620544
# g_loss: 1.8649183511734009
# Epoch:4846, dis_loss:0.36418963223695755
# Epoch:4846, gen_loss: 2.3305020928382874
# Batch:2
# d_loss :  0.3324600160121918
# g_loss: 2.5554189682006836
# Epoch:4846, dis_loss:0.35361309349536896
# Epoch:4846, gen_loss: 2.405474384625753
# Batch:3
# d_loss :  0.33725687861442566
# g_loss: 2.2213287353515625
# Epoch:4846, dis_loss:0.34952403977513313
# Epoch:4846, gen_loss: 2.359437972307205
# --------------------------
# Epoch is 4847
# Number of Batches :  4
# Batch:0
# d_loss :  0.33111853897571564
# g_loss: 2.4290080070495605
# Epoch:4847, dis_loss:0.33111853897571564
# Epoch:4847, gen_loss: 2.4290080070495605
# Batch:1
# d_loss :  0.350858673453331
# g_loss: 1.9656894207000732
# Epoch:4847, dis_loss:0.3409886062145233
# Epoch:4847, gen_loss: 2.197348713874817
# Batch:2
# d_loss :  0.3606140911579132
# g_loss: 2.9840292930603027
# Epoch:4847, dis_loss:0.34753043452898663
# Epoch:4847, gen_loss: 2.459575573603312
# Batch:3
# d_loss :  0.3883673846721649
# g_loss: 2.228330612182617
# Epoch:4847, dis_loss:0.3577396720647812
# Epoch:4847, gen_loss: 2.4017643332481384
# --------------------------
# Epoch is 4848
# Number of Batches :  4
# Batch:0
# d_loss :  0.3452148735523224
# g_loss: 2.0114359855651855
# Epoch:4848, dis_loss:0.3452148735523224
# Epoch:4848, gen_loss: 2.0114359855651855
# Batch:1
# d_loss :  0.3488328754901886
# g_loss: 2.2277371883392334
# Epoch:4848, dis_loss:0.3470238745212555
# Epoch:4848, gen_loss: 2.1195865869522095
# Batch:2
# d_loss :  0.34105120599269867
# g_loss: 2.076838970184326
# Epoch:4848, dis_loss:0.34503298501173657
# Epoch:4848, gen_loss: 2.105337381362915
# Batch:3
# d_loss :  0.3252902925014496
# g_loss: 1.940204381942749
# Epoch:4848, dis_loss:0.3400973118841648
# Epoch:4848, gen_loss: 2.0640541315078735
# --------------------------
# Epoch is 4849
# Number of Batches :  4
# Batch:0
# d_loss :  0.3388081192970276
# g_loss: 2.4541168212890625
# Epoch:4849, dis_loss:0.3388081192970276
# Epoch:4849, gen_loss: 2.4541168212890625
# Batch:1
# d_loss :  0.340726837515831
# g_loss: 2.1916604042053223
# Epoch:4849, dis_loss:0.3397674784064293
# Epoch:4849, gen_loss: 2.3228886127471924
# Batch:2
# d_loss :  0.33535531163215637
# g_loss: 2.17834210395813
# Epoch:4849, dis_loss:0.3382967561483383
# Epoch:4849, gen_loss: 2.2747064431508384
# Batch:3
# d_loss :  0.32238173484802246
# g_loss: 2.122418165206909
# Epoch:4849, dis_loss:0.33431800082325935
# Epoch:4849, gen_loss: 2.236634373664856
# --------------------------
# Epoch is 4850
# Number of Batches :  4
# Batch:0
# d_loss :  0.33605632185935974
# g_loss: 2.405768394470215
# Epoch:4850, dis_loss:0.33605632185935974
# Epoch:4850, gen_loss: 2.405768394470215
# Batch:1
# d_loss :  0.34391069412231445
# g_loss: 2.0714592933654785
# Epoch:4850, dis_loss:0.3399835079908371
# Epoch:4850, gen_loss: 2.2386138439178467
# Batch:2
# d_loss :  0.33504584431648254
# g_loss: 2.259195327758789
# Epoch:4850, dis_loss:0.33833762009938556
# Epoch:4850, gen_loss: 2.245474338531494
# Batch:3
# d_loss :  0.3428657501935959
# g_loss: 2.1962242126464844
# Epoch:4850, dis_loss:0.33946965262293816
# Epoch:4850, gen_loss: 2.2331618070602417
# --------------------------
# Epoch is 4851
# Number of Batches :  4
# Batch:0
# d_loss :  0.35517461597919464
# g_loss: 2.207684278488159
# Epoch:4851, dis_loss:0.35517461597919464
# Epoch:4851, gen_loss: 2.207684278488159
# Batch:1
# d_loss :  0.32824045419692993
# g_loss: 2.0001230239868164
# Epoch:4851, dis_loss:0.3417075350880623
# Epoch:4851, gen_loss: 2.103903651237488
# Batch:2
# d_loss :  0.33420151472091675
# g_loss: 2.1411666870117188
# Epoch:4851, dis_loss:0.3392055282990138
# Epoch:4851, gen_loss: 2.1163246631622314
# Batch:3
# d_loss :  0.3443058133125305
# g_loss: 2.6039018630981445
# Epoch:4851, dis_loss:0.34048059955239296
# Epoch:4851, gen_loss: 2.2382189631462097
# --------------------------
# Epoch is 4852
# Number of Batches :  4
# Batch:0
# d_loss :  0.34192807972431183
# g_loss: 2.0023744106292725
# Epoch:4852, dis_loss:0.34192807972431183
# Epoch:4852, gen_loss: 2.0023744106292725
# Batch:1
# d_loss :  0.3542066812515259
# g_loss: 2.664808750152588
# Epoch:4852, dis_loss:0.34806738048791885
# Epoch:4852, gen_loss: 2.33359158039093
# Batch:2
# d_loss :  0.3452790826559067
# g_loss: 2.1300597190856934
# Epoch:4852, dis_loss:0.3471379478772481
# Epoch:4852, gen_loss: 2.265747626622518
# Batch:3
# d_loss :  0.3362278491258621
# g_loss: 2.0547895431518555
# Epoch:4852, dis_loss:0.3444104231894016
# Epoch:4852, gen_loss: 2.2130081057548523
# --------------------------
# Epoch is 4853
# Number of Batches :  4
# Batch:0
# d_loss :  0.349466472864151
# g_loss: 2.7876133918762207
# Epoch:4853, dis_loss:0.349466472864151
# Epoch:4853, gen_loss: 2.7876133918762207
# Batch:1
# d_loss :  0.3500112146139145
# g_loss: 2.1782820224761963
# Epoch:4853, dis_loss:0.34973884373903275
# Epoch:4853, gen_loss: 2.4829477071762085
# Batch:2
# d_loss :  0.34076952934265137
# g_loss: 2.483860969543457
# Epoch:4853, dis_loss:0.34674907227357227
# Epoch:4853, gen_loss: 2.4832521279652915
# Batch:3
# d_loss :  0.33695317804813385
# g_loss: 2.384331703186035
# Epoch:4853, dis_loss:0.3443000987172127
# Epoch:4853, gen_loss: 2.4585220217704773
# --------------------------
# Epoch is 4854
# Number of Batches :  4
# Batch:0
# d_loss :  0.3448159247636795
# g_loss: 2.0290722846984863
# Epoch:4854, dis_loss:0.3448159247636795
# Epoch:4854, gen_loss: 2.0290722846984863
# Batch:1
# d_loss :  0.3358975946903229
# g_loss: 1.8619585037231445
# Epoch:4854, dis_loss:0.3403567597270012
# Epoch:4854, gen_loss: 1.9455153942108154
# Batch:2
# d_loss :  0.34253066778182983
# g_loss: 2.633321523666382
# Epoch:4854, dis_loss:0.3410813957452774
# Epoch:4854, gen_loss: 2.1747841040293374
# Batch:3
# d_loss :  0.3537551611661911
# g_loss: 2.018547296524048
# Epoch:4854, dis_loss:0.34424983710050583
# Epoch:4854, gen_loss: 2.135724902153015
# --------------------------
# Epoch is 4855
# Number of Batches :  4
# Batch:0
# d_loss :  0.3356141448020935
# g_loss: 2.2428677082061768
# Epoch:4855, dis_loss:0.3356141448020935
# Epoch:4855, gen_loss: 2.2428677082061768
# Batch:1
# d_loss :  0.3377053737640381
# g_loss: 2.1922359466552734
# Epoch:4855, dis_loss:0.3366597592830658
# Epoch:4855, gen_loss: 2.217551827430725
# Batch:2
# d_loss :  0.3225753456354141
# g_loss: 2.2015907764434814
# Epoch:4855, dis_loss:0.33196495473384857
# Epoch:4855, gen_loss: 2.212231477101644
# Batch:3
# d_loss :  0.32340382039546967
# g_loss: 2.1861579418182373
# Epoch:4855, dis_loss:0.32982467114925385
# Epoch:4855, gen_loss: 2.2057130932807922
# --------------------------
# Epoch is 4856
# Number of Batches :  4
# Batch:0
# d_loss :  0.3297617584466934
# g_loss: 2.4628548622131348
# Epoch:4856, dis_loss:0.3297617584466934
# Epoch:4856, gen_loss: 2.4628548622131348
# Batch:1
# d_loss :  0.3262135982513428
# g_loss: 2.1865317821502686
# Epoch:4856, dis_loss:0.3279876783490181
# ...
# g_loss: 2.1514768600463867
# Epoch:4975, dis_loss:0.3371675908565521
# Epoch:4975, gen_loss: 2.1514768600463867
# Batch:1
# d_loss :  0.3331427723169327
# g_loss: 2.347194194793701
# Epoch:4975, dis_loss:0.3351551815867424
# Epoch:4975, gen_loss: 2.249335527420044
# Batch:2
# d_loss :  0.3308238685131073
# g_loss: 2.1045520305633545
# Epoch:4975, dis_loss:0.3337114105621974
# Epoch:4975, gen_loss: 2.2010743618011475
# Batch:3
# d_loss :  0.33416908979415894
# g_loss: 2.284593343734741
# Epoch:4975, dis_loss:0.33382583037018776
# Epoch:4975, gen_loss: 2.221954107284546
# --------------------------
# Epoch is 4976
# Number of Batches :  4
# Batch:0
# d_loss :  0.3258039504289627
# g_loss: 2.2030067443847656
# Epoch:4976, dis_loss:0.3258039504289627
# Epoch:4976, gen_loss: 2.2030067443847656
# Batch:1
# d_loss :  0.32660388946533203
# g_loss: 2.288576602935791
# Epoch:4976, dis_loss:0.32620391994714737
# Epoch:4976, gen_loss: 2.2457916736602783
# Batch:2
# d_loss :  0.3585737943649292
# g_loss: 1.9154024124145508
# Epoch:4976, dis_loss:0.33699387808640796
# Epoch:4976, gen_loss: 2.1356619199117026
# Batch:3
# d_loss :  0.3420518636703491
# g_loss: 2.442899703979492
# Epoch:4976, dis_loss:0.33825837448239326
# Epoch:4976, gen_loss: 2.21247136592865
# --------------------------
# Epoch is 4977
# Number of Batches :  4
# Batch:0
# d_loss :  0.3375193774700165
# g_loss: 2.2870359420776367
# Epoch:4977, dis_loss:0.3375193774700165
# Epoch:4977, gen_loss: 2.2870359420776367
# Batch:1
# d_loss :  0.32295556366443634
# g_loss: 2.0550107955932617
# Epoch:4977, dis_loss:0.3302374705672264
# Epoch:4977, gen_loss: 2.171023368835449
# Batch:2
# d_loss :  0.3231220245361328
# g_loss: 2.339397430419922
# Epoch:4977, dis_loss:0.32786565522352856
# Epoch:4977, gen_loss: 2.2271480560302734
# Batch:3
# d_loss :  0.34501102566719055
# g_loss: 2.087362766265869
# Epoch:4977, dis_loss:0.33215199783444405
# Epoch:4977, gen_loss: 2.1922017335891724
# --------------------------
# Epoch is 4978
# Number of Batches :  4
# Batch:0
# d_loss :  0.3306845426559448
# g_loss: 2.3339133262634277
# Epoch:4978, dis_loss:0.3306845426559448
# Epoch:4978, gen_loss: 2.3339133262634277
# Batch:1
# d_loss :  0.34537461400032043
# g_loss: 2.0716497898101807
# Epoch:4978, dis_loss:0.33802957832813263
# Epoch:4978, gen_loss: 2.202781558036804
# Batch:2
# d_loss :  0.32771117985248566
# g_loss: 2.1594505310058594
# Epoch:4978, dis_loss:0.3345901121695836
# Epoch:4978, gen_loss: 2.1883378823598227
# Batch:3
# d_loss :  0.34417563676834106
# g_loss: 2.0802230834960938
# Epoch:4978, dis_loss:0.336986493319273
# Epoch:4978, gen_loss: 2.1613091826438904
# --------------------------
# Epoch is 4979
# Number of Batches :  4
# Batch:0
# d_loss :  0.3332844078540802
# g_loss: 2.1369595527648926
# Epoch:4979, dis_loss:0.3332844078540802
# Epoch:4979, gen_loss: 2.1369595527648926
# Batch:1
# d_loss :  0.3343484252691269
# g_loss: 2.181974411010742
# Epoch:4979, dis_loss:0.33381641656160355
# Epoch:4979, gen_loss: 2.1594669818878174
# Batch:2
# d_loss :  0.33846646547317505
# g_loss: 2.069390296936035
# Epoch:4979, dis_loss:0.3353664328654607
# Epoch:4979, gen_loss: 2.129441420237223
# Batch:3
# d_loss :  0.3347342163324356
# g_loss: 2.1824629306793213
# Epoch:4979, dis_loss:0.33520837873220444
# Epoch:4979, gen_loss: 2.142696797847748
# --------------------------
# Epoch is 4980
# Number of Batches :  4
# Batch:0
# d_loss :  0.33719536662101746
# g_loss: 2.2354559898376465
# Epoch:4980, dis_loss:0.33719536662101746
# Epoch:4980, gen_loss: 2.2354559898376465
# Batch:1
# d_loss :  0.3351929038763046
# g_loss: 2.1521856784820557
# Epoch:4980, dis_loss:0.33619413524866104
# Epoch:4980, gen_loss: 2.193820834159851
# Batch:2
# d_loss :  0.33547191321849823
# g_loss: 2.0313339233398438
# Epoch:4980, dis_loss:0.3359533945719401
# Epoch:4980, gen_loss: 2.139658530553182
# Batch:3
# d_loss :  0.3400617837905884
# g_loss: 2.316272497177124
# Epoch:4980, dis_loss:0.3369804918766022
# Epoch:4980, gen_loss: 2.1838120222091675
# --------------------------
# Epoch is 4981
# Number of Batches :  4
# Batch:0
# d_loss :  0.3453768789768219
# g_loss: 2.050295829772949
# Epoch:4981, dis_loss:0.3453768789768219
# Epoch:4981, gen_loss: 2.050295829772949
# Batch:1
# d_loss :  0.33709245920181274
# g_loss: 2.149940013885498
# Epoch:4981, dis_loss:0.3412346690893173
# Epoch:4981, gen_loss: 2.1001179218292236
# Batch:2
# d_loss :  0.31751349568367004
# g_loss: 2.450044870376587
# Epoch:4981, dis_loss:0.3333276112874349
# Epoch:4981, gen_loss: 2.216760238011678
# Batch:3
# d_loss :  0.34716296195983887
# g_loss: 2.025482177734375
# Epoch:4981, dis_loss:0.3367864489555359
# Epoch:4981, gen_loss: 2.1689407229423523
# --------------------------
# Epoch is 4982
# Number of Batches :  4
# Batch:0
# d_loss :  0.3453759551048279
# g_loss: 2.067721366882324
# Epoch:4982, dis_loss:0.3453759551048279
# Epoch:4982, gen_loss: 2.067721366882324
# Batch:1
# d_loss :  0.34699709713459015
# g_loss: 2.13814377784729
# Epoch:4982, dis_loss:0.346186526119709
# Epoch:4982, gen_loss: 2.102932572364807
# Batch:2
# d_loss :  0.3359963595867157
# g_loss: 2.080808162689209
# Epoch:4982, dis_loss:0.34278980394204456
# Epoch:4982, gen_loss: 2.095557769139608
# Batch:3
# d_loss :  0.3431776165962219
# g_loss: 2.1112606525421143
# Epoch:4982, dis_loss:0.3428867571055889
# Epoch:4982, gen_loss: 2.0994834899902344
# --------------------------
# Epoch is 4983
# Number of Batches :  4
# Batch:0
# d_loss :  0.34307536482810974
# g_loss: 2.0827677249908447
# Epoch:4983, dis_loss:0.34307536482810974
# Epoch:4983, gen_loss: 2.0827677249908447
# Batch:1
# d_loss :  0.3294590413570404
# g_loss: 2.3492298126220703
# Epoch:4983, dis_loss:0.3362672030925751
# Epoch:4983, gen_loss: 2.2159987688064575
# Batch:2
# d_loss :  0.33987627923488617
# g_loss: 1.9958113431930542
# Epoch:4983, dis_loss:0.33747022847334546
# Epoch:4983, gen_loss: 2.1426029602686563
# Batch:3
# d_loss :  0.33441483974456787
# g_loss: 2.4323861598968506
# Epoch:4983, dis_loss:0.33670638129115105
# Epoch:4983, gen_loss: 2.215048760175705
# --------------------------
# Epoch is 4984
# Number of Batches :  4
# Batch:0
# d_loss :  0.33719775080680847
# g_loss: 2.240602731704712
# Epoch:4984, dis_loss:0.33719775080680847
# Epoch:4984, gen_loss: 2.240602731704712
# Batch:1
# d_loss :  0.3236689865589142
# g_loss: 2.1885104179382324
# Epoch:4984, dis_loss:0.33043336868286133
# Epoch:4984, gen_loss: 2.214556574821472
# Batch:2
# d_loss :  0.3494822233915329
# g_loss: 2.110200881958008
# Epoch:4984, dis_loss:0.3367829869190852
# Epoch:4984, gen_loss: 2.179771343866984
# Batch:3
# d_loss :  0.3410269021987915
# g_loss: 2.224557876586914
# Epoch:4984, dis_loss:0.33784396573901176
# Epoch:4984, gen_loss: 2.1909679770469666
# --------------------------
# Epoch is 4985
# Number of Batches :  4
# Batch:0
# d_loss :  0.337986022233963
# g_loss: 2.084352493286133
# Epoch:4985, dis_loss:0.337986022233963
# Epoch:4985, gen_loss: 2.084352493286133
# Batch:1
# d_loss :  0.3403189927339554
# g_loss: 2.0951759815216064
# Epoch:4985, dis_loss:0.3391525074839592
# Epoch:4985, gen_loss: 2.0897642374038696
# Batch:2
# d_loss :  0.3380971848964691
# g_loss: 2.177910804748535
# Epoch:4985, dis_loss:0.33880073328812915
# Epoch:4985, gen_loss: 2.1191464265187583
# Batch:3
# d_loss :  0.34777122735977173
# g_loss: 2.049795150756836
# Epoch:4985, dis_loss:0.3410433568060398
# Epoch:4985, gen_loss: 2.1018086075782776
# --------------------------
# Epoch is 4986
# Number of Batches :  4
# Batch:0
# d_loss :  0.33350807428359985
# g_loss: 2.370802164077759
# Epoch:4986, dis_loss:0.33350807428359985
# Epoch:4986, gen_loss: 2.370802164077759
# Batch:1
# d_loss :  0.35088323056697845
# g_loss: 2.042126178741455
# Epoch:4986, dis_loss:0.34219565242528915
# Epoch:4986, gen_loss: 2.206464171409607
# Batch:2
# d_loss :  0.3283732831478119
# g_loss: 2.1625027656555176
# Epoch:4986, dis_loss:0.3375881959994634
# Epoch:4986, gen_loss: 2.191810369491577
# Batch:3
# d_loss :  0.3368174582719803
# g_loss: 2.3341634273529053
# Epoch:4986, dis_loss:0.3373955115675926
# Epoch:4986, gen_loss: 2.227398633956909
# --------------------------
# Epoch is 4987
# Number of Batches :  4
# Batch:0
# d_loss :  0.3346853405237198
# g_loss: 2.124680519104004
# Epoch:4987, dis_loss:0.3346853405237198
# Epoch:4987, gen_loss: 2.124680519104004
# Batch:1
# d_loss :  0.3260866701602936
# g_loss: 2.2685351371765137
# Epoch:4987, dis_loss:0.3303860053420067
# Epoch:4987, gen_loss: 2.196607828140259
# Batch:2
# d_loss :  0.33498264849185944
# g_loss: 2.195876121520996
# Epoch:4987, dis_loss:0.33191821972529095
# Epoch:4987, gen_loss: 2.196363925933838
# Batch:3
# d_loss :  0.33916330337524414
# g_loss: 2.1936516761779785
# Epoch:4987, dis_loss:0.33372949063777924
# Epoch:4987, gen_loss: 2.195685863494873
# --------------------------
# Epoch is 4988
# Number of Batches :  4
# Batch:0
# d_loss :  0.3548026382923126
# g_loss: 1.9602677822113037
# Epoch:4988, dis_loss:0.3548026382923126
# Epoch:4988, gen_loss: 1.9602677822113037
# Batch:1
# d_loss :  0.3357033282518387
# g_loss: 2.574801445007324
# Epoch:4988, dis_loss:0.34525298327207565
# Epoch:4988, gen_loss: 2.267534613609314
# Batch:2
# d_loss :  0.3352953791618347
# g_loss: 2.148982524871826
# Epoch:4988, dis_loss:0.34193378190199536
# Epoch:4988, gen_loss: 2.228017250696818
# Batch:3
# d_loss :  0.3426554948091507
# g_loss: 2.1477553844451904
# Epoch:4988, dis_loss:0.3421142101287842
# Epoch:4988, gen_loss: 2.207951784133911
# --------------------------
# Epoch is 4989
# Number of Batches :  4
# Batch:0
# d_loss :  0.3377254009246826
# g_loss: 2.22676682472229
# Epoch:4989, dis_loss:0.3377254009246826
# Epoch:4989, gen_loss: 2.22676682472229
# Batch:1
# d_loss :  0.3480108380317688
# g_loss: 2.1314077377319336
# Epoch:4989, dis_loss:0.3428681194782257
# Epoch:4989, gen_loss: 2.179087281227112
# Batch:2
# d_loss :  0.3346513509750366
# g_loss: 2.017819404602051
# Epoch:4989, dis_loss:0.34012919664382935
# Epoch:4989, gen_loss: 2.1253313223520913
# Batch:3
# d_loss :  0.3520820736885071
# g_loss: 2.2878642082214355
# Epoch:4989, dis_loss:0.3431174159049988
# Epoch:4989, gen_loss: 2.1659645438194275
# --------------------------
# Epoch is 4990
# Number of Batches :  4
# Batch:0
# d_loss :  0.3527319133281708
# g_loss: 2.042280912399292
# Epoch:4990, dis_loss:0.3527319133281708
# Epoch:4990, gen_loss: 2.042280912399292
# Batch:1
# d_loss :  0.3426325172185898
# g_loss: 2.0759918689727783
# Epoch:4990, dis_loss:0.3476822152733803
# Epoch:4990, gen_loss: 2.059136390686035
# Batch:2
# d_loss :  0.32747378945350647
# g_loss: 2.3622870445251465
# Epoch:4990, dis_loss:0.34094607333342236
# Epoch:4990, gen_loss: 2.1601866086324057
# Batch:3
# d_loss :  0.3485725373029709
# g_loss: 2.0508251190185547
# Epoch:4990, dis_loss:0.3428526893258095
# Epoch:4990, gen_loss: 2.132846236228943
# --------------------------
# Epoch is 4991
# Number of Batches :  4
# Batch:0
# d_loss :  0.3302117884159088
# g_loss: 2.232252836227417
# Epoch:4991, dis_loss:0.3302117884159088
# Epoch:4991, gen_loss: 2.232252836227417
# Batch:1
# d_loss :  0.35146911442279816
# g_loss: 2.0878005027770996
# Epoch:4991, dis_loss:0.3408404514193535
# Epoch:4991, gen_loss: 2.1600266695022583
# Batch:2
# d_loss :  0.33205026388168335
# g_loss: 2.2621917724609375
# Epoch:4991, dis_loss:0.33791038890679675
# Epoch:4991, gen_loss: 2.194081703821818
# Batch:3
# d_loss :  0.3574940115213394
# g_loss: 2.0977816581726074
# Epoch:4991, dis_loss:0.34280629456043243
# Epoch:4991, gen_loss: 2.1700066924095154
# --------------------------
# Epoch is 4992
# Number of Batches :  4
# Batch:0
# d_loss :  0.3417079448699951
# g_loss: 2.298337459564209
# Epoch:4992, dis_loss:0.3417079448699951
# Epoch:4992, gen_loss: 2.298337459564209
# Batch:1
# d_loss :  0.33347007632255554
# g_loss: 2.0806641578674316
# Epoch:4992, dis_loss:0.33758901059627533
# Epoch:4992, gen_loss: 2.1895008087158203
# Batch:2
# d_loss :  0.32938387989997864
# g_loss: 2.1799354553222656
# Epoch:4992, dis_loss:0.3348539670308431
# Epoch:4992, gen_loss: 2.1863123575846353
# Batch:3
# d_loss :  0.3417849987745285
# g_loss: 2.2213332653045654
# Epoch:4992, dis_loss:0.33658672496676445
# Epoch:4992, gen_loss: 2.195067584514618
# --------------------------
# Epoch is 4993
# Number of Batches :  4
# Batch:0
# d_loss :  0.33851753175258636
# g_loss: 2.1414904594421387
# Epoch:4993, dis_loss:0.33851753175258636
# Epoch:4993, gen_loss: 2.1414904594421387
# Batch:1
# d_loss :  0.3373611867427826
# g_loss: 2.0462217330932617
# Epoch:4993, dis_loss:0.3379393592476845
# Epoch:4993, gen_loss: 2.0938560962677
# Batch:2
# d_loss :  0.3370751589536667
# g_loss: 2.4570536613464355
# Epoch:4993, dis_loss:0.3376512924830119
# Epoch:4993, gen_loss: 2.2149219512939453
# Batch:3
# d_loss :  0.34904494881629944
# g_loss: 2.456247568130493
# Epoch:4993, dis_loss:0.34049970656633377
# Epoch:4993, gen_loss: 2.2752533555030823
# --------------------------
# Epoch is 4994
# Number of Batches :  4
# Batch:0
# d_loss :  0.3317835032939911
# g_loss: 2.208695650100708
# Epoch:4994, dis_loss:0.3317835032939911
# Epoch:4994, gen_loss: 2.208695650100708
# Batch:1
# d_loss :  0.3433929830789566
# g_loss: 2.1650478839874268
# Epoch:4994, dis_loss:0.33758824318647385
# Epoch:4994, gen_loss: 2.1868717670440674
# Batch:2
# d_loss :  0.3386605829000473
# g_loss: 2.063014268875122
# Epoch:4994, dis_loss:0.337945689757665
# Epoch:4994, gen_loss: 2.1455859343210855
# Batch:3
# d_loss :  0.33249762654304504
# g_loss: 2.1974010467529297
# Epoch:4994, dis_loss:0.33658367395401
# Epoch:4994, gen_loss: 2.1585397124290466
# --------------------------
# Epoch is 4995
# Number of Batches :  4
# Batch:0
# d_loss :  0.3329930305480957
# g_loss: 2.3569812774658203
# Epoch:4995, dis_loss:0.3329930305480957
# Epoch:4995, gen_loss: 2.3569812774658203
# Batch:1
# d_loss :  0.35497188568115234
# g_loss: 2.1276192665100098
# Epoch:4995, dis_loss:0.343982458114624
# Epoch:4995, gen_loss: 2.242300271987915
# Batch:2
# d_loss :  0.34811966121196747
# g_loss: 2.0543253421783447
# Epoch:4995, dis_loss:0.3453615258137385
# Epoch:4995, gen_loss: 2.1796419620513916
# Batch:3
# d_loss :  0.35966427624225616
# g_loss: 2.608194351196289
# Epoch:4995, dis_loss:0.3489372134208679
# Epoch:4995, gen_loss: 2.286780059337616
# --------------------------
# Epoch is 4996
# Number of Batches :  4
# Batch:0
# d_loss :  0.3610360622406006
# g_loss: 2.106218099594116
# Epoch:4996, dis_loss:0.3610360622406006
# Epoch:4996, gen_loss: 2.106218099594116
# Batch:1
# d_loss :  0.3399731069803238
# g_loss: 2.139436721801758
# Epoch:4996, dis_loss:0.3505045846104622
# Epoch:4996, gen_loss: 2.122827410697937
# Batch:2
# d_loss :  0.33137890696525574
# g_loss: 2.2005722522735596
# Epoch:4996, dis_loss:0.3441293587287267
# Epoch:4996, gen_loss: 2.148742357889811
# Batch:3
# d_loss :  0.3469489961862564
# g_loss: 2.1089019775390625
# Epoch:4996, dis_loss:0.34483426809310913
# Epoch:4996, gen_loss: 2.138782262802124
# --------------------------
# Epoch is 4997
# Number of Batches :  4
# Batch:0
# d_loss :  0.3368307203054428
# g_loss: 2.0122690200805664
# Epoch:4997, dis_loss:0.3368307203054428
# Epoch:4997, gen_loss: 2.0122690200805664
# Batch:1
# d_loss :  0.3333268463611603
# g_loss: 2.2551138401031494
# Epoch:4997, dis_loss:0.33507878333330154
# Epoch:4997, gen_loss: 2.133691430091858
# Batch:2
# d_loss :  0.3319863975048065
# g_loss: 2.1057474613189697
# Epoch:4997, dis_loss:0.33404798805713654
# Epoch:4997, gen_loss: 2.1243767738342285
# Batch:3
# d_loss :  0.34239187836647034
# g_loss: 2.170717239379883
# Epoch:4997, dis_loss:0.33613396063447
# Epoch:4997, gen_loss: 2.135961890220642
# --------------------------
# Epoch is 4998
# Number of Batches :  4
# Batch:0
# d_loss :  0.3347775787115097
# g_loss: 2.21909761428833
# Epoch:4998, dis_loss:0.3347775787115097
# Epoch:4998, gen_loss: 2.21909761428833
# Batch:1
# d_loss :  0.34102925658226013
# g_loss: 2.063603162765503
# Epoch:4998, dis_loss:0.3379034176468849
# Epoch:4998, gen_loss: 2.1413503885269165
# Batch:2
# d_loss :  0.33858805894851685
# g_loss: 2.256376266479492
# Epoch:4998, dis_loss:0.3381316314140956
# Epoch:4998, gen_loss: 2.179692347844442
# Batch:3
# d_loss :  0.35553498566150665
# g_loss: 2.242408275604248
# Epoch:4998, dis_loss:0.34248246997594833
# Epoch:4998, gen_loss: 2.1953713297843933
# --------------------------
# Epoch is 4999
# Number of Batches :  4
# Batch:0
# d_loss :  0.3438975363969803
# g_loss: 2.308504343032837
# Epoch:4999, dis_loss:0.3438975363969803
# Epoch:4999, gen_loss: 2.308504343032837
# Batch:1
# d_loss :  0.3234230875968933
# g_loss: 2.217130661010742
# Epoch:4999, dis_loss:0.3336603119969368
# Epoch:4999, gen_loss: 2.2628175020217896
# Batch:2
# d_loss :  0.3429958075284958
# g_loss: 2.214717388153076
# Epoch:4999, dis_loss:0.3367721438407898
# Epoch:4999, gen_loss: 2.2467841307322183
# Batch:3
# d_loss :  0.3415505588054657
# g_loss: 2.2836568355560303
# Epoch:4999, dis_loss:0.33796674758195877
# Epoch:4999, gen_loss: 2.2560023069381714
# Time: 10564.837946653366

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python3 scipy --version
# Out:
# (null): can't open file 'scipy': [Errno 2] No such file or directory
